# %% [markdown]
# # Regulation Inspection

# %% [markdown]
# The goal is to get an understanding on how regulations work.
#
# My focus is on WX regulations.
# According to the document "CRIDA-Regulations-20160401-20160430.csv", regulations have the following properties:
#
# | dateReference | RegulationStart   | RegulationId | TrafficVolumeSet | ReferenceLocation | ReferenceLocationType | TrafficVolume | RegulationEnd     | RegulationActivity | RegulationCancelTime | RegulationDuration | AiracCycle | RegulationCategory | RegulationReasonCode | RegulationDescription |
# |---------------|-------------------|--------------|------------------|-------------------|-----------------------|---------------|-------------------|--------------------|----------------------|--------------------|------------|--------------------|----------------------|-----------------------|
# | 20160401      | 20160401 04:40:00 | EDDFA01      | EDGGFMP1         | EDDF              | AD                    | EDDFAWX       | 20160401 07:20:00 | C                  | 20160401 05:52:57    | 72                 | 411        | T                  | W                    | STRONG WINDS          |
# | 20160401      | 20160401 06:00:00 | LEBLA01M     | LECBFMP          | LEBL              | AD                    | LEBLARR       | 20160401 13:00:00 | C                  | 20160401 11:41:42    | 341                | 411        | T                  | W                    | CB + STORM            |
# | 20160401      | 20160401 08:40:00 | LECVN01M     | LECBFMP          | LECBCVN           | AS                    | LECBCVN1      | 20160401 11:20:00 | C                  | 20160401 08:16:03    | -23                | 411        | T                  | C                    |                       |
#
#
#
# Acc. "DatAcron Data sources for Flow Management scenarios.pptx", Traffic Volume is the sector name.
#
# These are three typical examples for WX-caused regulations. It is important to note the column "referenceLocation" which indicates us that the critical weather, that caused the regulation, is not co-located with the regulated sector. Note also the "referenceLocationType", which denotes if the area of interest is an airport or an airspace.
#
# The second important column is the "RegulationCancelTime", which denotes that a regulation may be cancelled if, for example, the actual weather turns out to be better than expected, or the network resilience is good enough to cope with demand exceeding capacity. The third regulation was even cancelled before it begun, yielding a negative "regulation time".
#
#
#
# With the following data exploration, I hope to pull these important properties of the regulation out of the data store.

# %%
import pandas as pd
from pandas.io.json import json_normalize, read_json
from SPARQLWrapper import SPARQLWrapper, JSON, XML, RDF

#import my connection module which allows to connect to the datAcron rdf store
from datacron_connector import TripleStoreConnector

ts107 = TripleStoreConnector(0)
ts109 = TripleStoreConnector(1)

# %% [markdown]
# Let's check what kind of regulations are stored in the triple store.

# %% [markdown]
# ## Get all airblocks of spain
#
# First, I will get all airblocks, together with their airspaces and super-airspaces.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT  ?bigairspace ?airspace ?block ?wkt ?lowerlevel ?upperlevel
WHERE { 
   
   # ?airspace dul:hasPart       ?block .
   # ?block       :hasLowerLevel ?lowerlevel ;
                :hasUpperLevel ?upperlevel ;
                :hasGeometry   ?geom.
   # ?geom        :hasMBR_WKT  ?wkt .
   
   OPTIONAL {?bigairspace dul:hasPart ?airspace. 
             #?conf           :configurationOfAirspace ?bigairspace ;
             #             dul:hasConstituent          ?t.
             #?t :TimeStart ?start ;
             #   :TimeEnd ?end.
             }.
   
   FILTER regex(str(?block), 'Airblock_LE', "i")
}
"""

df2 = ts109.query(qry)
df2 = ts109.clean(df2)
# %time df2 = df2.sort_values('block')

df2.to_csv('data/allspanishairblocks.csv')
df2.head(10)
# Out:
# CPU times: user 12 ms, sys: 4 ms, total: 16 ms
# Wall time: 25.9 ms
#             bigairspace             airspace                  block  \
# 0  Airspace_LEABTMA_411  Airspace_LEABTA_411  Airblock_LEABTA_249LE
# 1    Airspace_LETOT_411  Airspace_LEABTA_411  Airblock_LEABTA_249LE
# 2  Airspace_LEAMTMA_411  Airspace_LEAMTA_411  Airblock_LEAMTA_650LE
# 3    Airspace_LETOT_411  Airspace_LEAMTA_411  Airblock_LEAMTA_650LE
# 4  Airspace_LEAMTMA_411  Airspace_LEAMTA_411  Airblock_LEAMTA_651LE
# 5    Airspace_LETOT_411  Airspace_LEAMTA_411  Airblock_LEAMTA_651LE
# 6  Airspace_LEAMTMA_411  Airspace_LEAMTA_411  Airblock_LEAMTA_652LE
# 7    Airspace_LETOT_411  Airspace_LEAMTA_411  Airblock_LEAMTA_652LE
# 9    Airspace_LETOT_411  Airspace_LEAMTA_411  Airblock_LEAMTA_653LE
# 8  Airspace_LEAMTMA_411  Airspace_LEAMTA_411  Airblock_LEAMTA_653LE
#
#                                                  wkt lowerlevel upperlevel
# 0  POLYGON ((-2.99166666666667 39, -2.99166666666...        0.0     7467.6
# 1  POLYGON ((-2.99166666666667 39, -2.99166666666...        0.0     7467.6
# 2  POLYGON ((-2.84083333333333 36.4166666666667, ...        0.0     4419.6
# 3  POLYGON ((-2.84083333333333 36.4166666666667, ...        0.0     4419.6
# 4  POLYGON ((-1.83333333333333 36.85, -1.83333333...        0.0     4419.6
# 5  POLYGON ((-1.83333333333333 36.85, -1.83333333...        0.0     4419.6
# 6  POLYGON ((-1.86111111111111 36.7138888888889, ...        0.0     4419.6
# 7  POLYGON ((-1.86111111111111 36.7138888888889, ...        0.0     4419.6
# 9  POLYGON ((-1.92361111111111 36.4530555555556, ...        0.0     4419.6
# 8  POLYGON ((-1.92361111111111 36.4530555555556, ...        0.0     4419.6

# %%
print(df2.iloc[0]['wkt'])
# Out:
# POLYGON ((-2.99166666666667 39, -2.99166666666667 39.4055555555556, -1.39444444444444 39.4055555555556, -1.39444444444444 39, -2.99166666666667 39))

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT  ?lowerlevel ?upperlevel ?s (myfn:getGeom(?s) as ?actualGeom)
WHERE { :Airblock_LEABTA_249LE :hasLowerLevel ?lowerlevel ;
                :hasUpperLevel ?upperlevel ;
                :hasGeometry   ?s.
}
"""

df3 = ts109.query(qry)
df3 = ts109.clean(df3)

df3.head()
# Out:
#   lowerlevel upperlevel                                                 s  \
# 0        0.0     7467.6  http://83.212.239.107/geometries/airblocks/249LE
#
#                                           actualGeom
# 0  POLYGON ((-1.7525 39.4055555555556, -1.3944444...

# %%
df3.iloc[0]['actualGeom']
# Out:
# 'POLYGON ((-1.7525 39.4055555555556, -1.39444444444444 39, -1.48277777777778 39, -2.915 39, -2.99166666666667 39, -2.98333333333333 39.0666666666667, -2.9 39.2, -2.75 39.2666666666667, -1.7525 39.4055555555556))'

# %% [markdown]
# ## Get all information about the three regulations above
#
# First, I will check what kind of regulations are available and then, I will check what information is available on the three regulations from the example in the introduction.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT ?s
WHERE {
  # ?s rdfs:subClassOf* :FM_Regulation .
}
"""
 #?s rdf:type/rdfs:subClassOf* :SpatiotemporalRegion 

df = ts107.query(qry)
df = ts107.clean(df)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-2-3d8aeba18e51> in <module>()
#      10  #?s rdf:type/rdfs:subClassOf* :SpatiotemporalRegion
#      11
# ---> 12 df = ts107.query(qry)
#      13 df = ts107.clean(df)
#      14 df.head(10)
#
# /home/joerg/jsnotes/1_datAcron/datacron_connector.py in query(self, query)
#      46
#      47
# ---> 48         result = self.sparql.query().convert()
#      49
#      50         #clean up the column mess (thanks to David Knodt)
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#     599             @rtype: L{QueryResult} instance
#     600         """
# --> 601         return QueryResult(self._query())
#     602
#     603     def queryAndConvert(self):
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     569
#     570         try:
# --> 571             response = urlopener(request)
#     572             return response, self.returnFormat
#     573         except urllib.error.HTTPError as e:
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 110] Connection timed out>

# %% [markdown]
# What properties are available for the WX regulations? I hope to see some of the columns listed in the introduction.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT DISTINCT ?p
WHERE {
  # ?s a :ATC_WeatherRegulation ; 
     # ?p ?o .
}
"""
df = ts109.query(qry)
df = ts109.clean(df)

df
# Out:
#                        p
# 0                   type
# 1              hasRegion
# 2        hasTimeInterval
# 3   RegulationAiracCycle
# 4  RegulationDescription
# 5   hasReferenceLocation

# %% [markdown]
# PROBLEM
#
# It seems that at least the
#
#  - reference location
#  - reference location type
#  - and the cancellation time
#
# are not available. Maybe hidden somewhere? I will inspect further. In the next query, I inspect all properties of the three regulations cited above.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT *
WHERE {
  VALUES ?s {:EDDFA01_411 :LEBLA01M_411 :LECVN01M_411} 
  # ?s dul:hasRegion             ?trafficVolume ;
        :hasReferenceLocation ?refLoc ;
 :RegulationDescription ?description ;
    dul:hasTimeInterval       ?time  ;
        a                     ?stype.

 # ?time :TimeStart ?start ;
       :TimeEnd   ?end .
}
"""

reguls = ts109.query(qry)
reguls = ts109.clean(reguls)
reguls.to_csv('data/regulations.csv')
reguls.head(20)
# Out:
#               s         trafficVolume                           refLoc  \
# 0   EDDFA01_411     Airspace_EDDF_411     Place_Frankfurt_Main_Airport
# 1  LEBLA01M_411     Airspace_LEBL_411  Place_Barcelona_El_Prat_Airport
# 2  LECVN01M_411  Airspace_LECBCVN_411             Airspace_LECBCVN_411
#
#      description                              time                  stype  \
# 0  STRONG WINDS_  intv_1459485600000_1459495200000  ATC_WeatherRegulation
# 1    CB + STORM_  intv_1459490400000_1459515600000  ATC_WeatherRegulation
# 2              _  intv_1459500000000_1459509600000           ATC_Capacity
#
#                  start                  end
# 0  2016-04-01T04:40:00  2016-04-01T05:52:57
# 1  2016-04-01T06:00:00  2016-04-01T11:41:42
# 2  2016-04-01T08:40:00  2016-04-01T08:16:03

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT *
WHERE {
  :Airspace_LETOT_411 ?p ?o
}
"""

space = ts109.query(qry)
space = ts109.clean(space)
space.head(20)
# Out:
#           p                     o
# 0      type           FM_Airspace
# 1   hasPart  Airspace_LECBPP2_411
# 2   hasPart  Airspace_LECMDGU_411
# 3   hasPart  Airspace_LECMTLU_411
# 4   hasPart  Airspace_LECMPAU_411
# 5   hasPart  Airspace_GCCCAAC_411
# 6   hasPart  Airspace_LECMDGL_411
# 7   hasPart  Airspace_LECBP1U_411
# 8   hasPart  Airspace_LECBLVU_411
# 9   hasPart  Airspace_GCCCRNE_411
# 10  hasPart  Airspace_LECMASU_411
# 11  hasPart  Airspace_LECMZGZ_411
# 12  hasPart  Airspace_GCCCOCE_411
# 13  hasPart  Airspace_GCCCRCE_411
# 14  hasPart  Airspace_GCCCRCW_411
# 15  hasPart  Airspace_GCCCRNW_411
# 16  hasPart  Airspace_GCCCRST_411
# 17  hasPart  Airspace_GCCCRWW_411
# 18  hasPart  Airspace_GCCCACW_411
# 19  hasPart  Airspace_GCCCFCN_411

# %% [markdown]
# UPDATE
#
# Good:
#  - The referenceLocation are now encoded.
#  - The 109 yields the required results. The times are correct now.
#  - But still entering the "sector" value from the regulations query does not get me any further.
#
# To Do:
#  - Somehow, I need to get from regulations to airblocks.
#  - Maybe something wrong with my queries?
#  - Here the answer from Giorgos: Comment 8: "Getting from regulations to airblocks is currently possible, with the following query:"

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT ?regulation ?airspace ?refloc (myfn:getGeom(?g) as ?WKT) ?low ?high ?config ?open ?close
WHERE {
  # ?regulation      a             ?type .
  # ?type       rdfs:subClassOf    :FM_Regulation .
  # ?regulation  dul:hasRegion     ?airspace ;
                  :hasReferenceLocation ?refloc ;
               dul:hasTimeInterval       ?regtime  .
   # ?regtime       :TimeStart             ?regstart ;
                  :TimeEnd               ?regend .

  # ?airspace    dul:hasPart       ?s .
  # ?s           dul:hasPart       ?b .
  # ?b              :hasGeometry   ?g ;
                  :hasLowerLevel ?low ;
                  :hasUpperLevel ?high .
                  
                  
   # ?config a :FM_Configuration ;
             :configurationOfAirspace ?airspace ;
          dul:hasConstituent          ?period .
   # ?period   :TimeStart               ?open ;
             :TimeEnd                 ?close.
} LIMIT 1000

"""

regs_and_spaces = ts109.query(qry)
regs_and_spaces = ts109.clean(regs_and_spaces)
regs_and_spaces.head(60)
# Out:
#       regulation              airspace                refloc  \
# 0   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 1   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 2   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 3   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 4   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 5   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 6   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 7   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 8   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 9   LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 10  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 11  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 12  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 13  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 14  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 15  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 16  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 17  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 18  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 19  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 20  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 21  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 22  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 23  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 24  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 25  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 26  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 27  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 28  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 29  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 30  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 31  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 32  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 33  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 34  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 35  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 36  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 37  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 38  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 39  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 40  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 41  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 42  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 43  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 44  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 45  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 46  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 47  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 48  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 49  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 50  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 51  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 52  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 53  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 54  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 55  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 56  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 57  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 58  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
# 59  LFMLE05E_411  Airspace_LFMLTMA_411  Airspace_LFMLTMA_411
#
#                                                   WKT                 low  \
# 0   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 1   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 2   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 3   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 4   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 5   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 6   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 7   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 8   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 9   POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 10  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 11  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 12  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 13  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 14  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 15  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 16  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 17  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 18  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 19  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 20  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 21  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 22  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 23  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 24  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 25  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 26  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 27  POLYGON ((5.18638888888889 43.4675, 5.21638888...                 0.0
# 28  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 29  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 30  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 31  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 32  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 33  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 34  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 35  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 36  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 37  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 38  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 39  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 40  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 41  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 42  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 43  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 44  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 45  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 46  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 47  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 48  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 49  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 50  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 51  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 52  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 53  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 54  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 55  POLYGON ((6.00361111111111 43.3125, 6.025 43.1...                 0.0
# 56  POLYGON ((4.16055555555556 43.6252777777778, 4...  2895.6000000000004
# 57  POLYGON ((4.16055555555556 43.6252777777778, 4...  2895.6000000000004
# 58  POLYGON ((4.16055555555556 43.6252777777778, 4...  2895.6000000000004
# 59  POLYGON ((4.16055555555556 43.6252777777778, 4...  2895.6000000000004
#
#                   high                                 config  \
# 0               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 1               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 2               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 3               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 4               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 5               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 6               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 7               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 8               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 9               4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 10              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 11              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 12              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 13              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 14              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 15              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 16              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 17              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 18              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 19              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 20              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 21              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 22              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 23              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 24              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 25              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 26              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 27              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 28  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 29  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 30  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 31  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 32  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 33  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 34  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 35  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 36  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 37  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 38  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 39  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 40  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 41  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 42  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 43  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 44  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 45  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 46  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 47  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 48  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 49  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 50  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 51  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 52  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 53  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 54  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 55  3505.2000000000003  AirspaceConfiguration_LFMLTMA_C1A_411
# 56              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 57              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 58              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
# 59              4419.6  AirspaceConfiguration_LFMLTMA_C1A_411
#
#                    open                close
# 0   2016-03-31T00:00:00  2016-03-31T23:59:00
# 1   2016-04-01T00:00:00  2016-04-01T23:59:00
# 2   2016-04-02T00:00:00  2016-04-02T23:59:00
# 3   2016-04-03T00:00:00  2016-04-03T23:59:00
# 4   2016-04-04T00:00:00  2016-04-04T23:59:00
# 5   2016-04-05T00:00:00  2016-04-05T23:59:00
# 6   2016-04-06T00:00:00  2016-04-06T23:59:00
# 7   2016-04-07T00:00:00  2016-04-07T23:59:00
# 8   2016-04-08T00:00:00  2016-04-08T23:59:00
# 9   2016-04-09T00:00:00  2016-04-09T23:59:00
# 10  2016-04-10T00:00:00  2016-04-10T23:59:00
# 11  2016-04-11T00:00:00  2016-04-11T23:59:00
# 12  2016-04-12T00:00:00  2016-04-12T23:59:00
# 13  2016-04-13T00:00:00  2016-04-13T23:59:00
# 14  2016-04-14T00:00:00  2016-04-14T23:59:00
# 15  2016-04-15T00:00:00  2016-04-15T23:59:00
# 16  2016-04-16T00:00:00  2016-04-16T23:59:00
# 17  2016-04-17T00:00:00  2016-04-17T23:59:00
# 18  2016-04-18T00:00:00  2016-04-18T23:59:00
# 19  2016-04-19T00:00:00  2016-04-19T23:59:00
# 20  2016-04-20T00:00:00  2016-04-20T23:59:00
# 21  2016-04-21T00:00:00  2016-04-21T23:59:00
# 22  2016-04-22T00:00:00  2016-04-22T23:59:00
# 23  2016-04-23T00:00:00  2016-04-23T23:59:00
# 24  2016-04-24T00:00:00  2016-04-24T23:59:00
# 25  2016-04-25T00:00:00  2016-04-25T23:59:00
# 26  2016-04-26T00:00:00  2016-04-26T23:59:00
# 27  2016-04-27T00:00:00  2016-04-27T23:59:00
# 28  2016-03-31T00:00:00  2016-03-31T23:59:00
# 29  2016-04-01T00:00:00  2016-04-01T23:59:00
# 30  2016-04-02T00:00:00  2016-04-02T23:59:00
# 31  2016-04-03T00:00:00  2016-04-03T23:59:00
# 32  2016-04-04T00:00:00  2016-04-04T23:59:00
# 33  2016-04-05T00:00:00  2016-04-05T23:59:00
# 34  2016-04-06T00:00:00  2016-04-06T23:59:00
# 35  2016-04-07T00:00:00  2016-04-07T23:59:00
# 36  2016-04-08T00:00:00  2016-04-08T23:59:00
# 37  2016-04-09T00:00:00  2016-04-09T23:59:00
# 38  2016-04-10T00:00:00  2016-04-10T23:59:00
# 39  2016-04-11T00:00:00  2016-04-11T23:59:00
# 40  2016-04-12T00:00:00  2016-04-12T23:59:00
# 41  2016-04-13T00:00:00  2016-04-13T23:59:00
# 42  2016-04-14T00:00:00  2016-04-14T23:59:00
# 43  2016-04-15T00:00:00  2016-04-15T23:59:00
# 44  2016-04-16T00:00:00  2016-04-16T23:59:00
# 45  2016-04-17T00:00:00  2016-04-17T23:59:00
# 46  2016-04-18T00:00:00  2016-04-18T23:59:00
# 47  2016-04-19T00:00:00  2016-04-19T23:59:00
# 48  2016-04-20T00:00:00  2016-04-20T23:59:00
# 49  2016-04-21T00:00:00  2016-04-21T23:59:00
# 50  2016-04-22T00:00:00  2016-04-22T23:59:00
# 51  2016-04-23T00:00:00  2016-04-23T23:59:00
# 52  2016-04-24T00:00:00  2016-04-24T23:59:00
# 53  2016-04-25T00:00:00  2016-04-25T23:59:00
# 54  2016-04-26T00:00:00  2016-04-26T23:59:00
# 55  2016-04-27T00:00:00  2016-04-27T23:59:00
# 56  2016-03-31T00:00:00  2016-03-31T23:59:00
# 57  2016-04-01T00:00:00  2016-04-01T23:59:00
# 58  2016-04-02T00:00:00  2016-04-02T23:59:00
# 59  2016-04-03T00:00:00  2016-04-03T23:59:00

# %%
len(regs_and_spaces)
# Out:
# 1000

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT ?airspace ?refloc #(myfn:getGeom(?g) as ?WKT) ?low ?high
WHERE {
  :LEBLA01M_411 dul:hasRegion     ?airspace ;
                  :hasReferenceLocation ?refloc.
 # ?airspace    dul:hasPart       ?s .
#  ?s           dul:hasPart       ?b .
#  ?b              :hasGeometry   ?g ;
 #                 :hasLowerLevel ?low ;
#                  :hasUpperLevel ?high .
} limit 100

"""

regs_and_spaces = ts109.query(qry)
regs_and_spaces = ts109.clean(regs_and_spaces)
regs_and_spaces.head(60)
# Out:
#             airspace                           refloc
# 0  Airspace_LEBL_411  Place_Barcelona_El_Prat_Airport

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT ?regulation ?airspace #(myfn:getGeom(?g) as ?WKT) 
WHERE {
  # ?regulation      a             ?type .
  # ?type       rdfs:subClassOf    :FM_Regulation .
  # ?regulation  dul:hasRegion     ?airspace .
  # ?airspace    dul:hasPart*      ?b .
  # ?b              :hasGeometry   ?g
} limit 10

"""

regs_and_spaces = ts109.query(qry)
regs_and_spaces = ts109.clean(regs_and_spaces)
regs_and_spaces.head(20)
# Out:
# Empty DataFrame
# Columns: [regulation, airspace]
# Index: []

# %% [markdown]
# Unfortunately, it does not seem to work out!
#
#
# The next query used to misbehave before, but it is now fixed thanks to Giorgos Comment #9

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT ?s ?sector ?time ?refloc ?description ?start ?end ?duration
WHERE {
  VALUES ?s {:EDDFA01_411 :LEBLA01M_411 :LECVN01M_411 } 
  # ?s dul:hasRegion             ?sector ;
        :hasReferenceLocation        ?refloc ;
        :RegulationDescription ?description ;
     dul:hasTimeInterval       ?time .
   
   # ?time :TimeStart ?start ;
        :TimeEnd   ?end ; 
        :duration ?duration .

        
}
""" 

df = ts109.query(qry)
df = ts109.clean(df)
df.head(20)
# Out:
#               s             sector                              time  \
# 0   EDDFA01_411  Airspace_EDDF_411  intv_1459485600000_1459495200000
# 1  LEBLA01M_411  Airspace_LEBL_411  intv_1459490400000_1459515600000
#
#                             refloc    description                start  \
# 0     Place_Frankfurt_Main_Airport  STRONG WINDS_  2016-04-01T04:40:00
# 1  Place_Barcelona_El_Prat_Airport    CB + STORM_  2016-04-01T06:00:00
#
#                    end duration
# 0  2016-04-01T05:52:57       72
# 1  2016-04-01T11:41:42      341

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT ?p ?o
WHERE {
  :Place_Frankfurt_Main_Airport ?p ?o

        
}
""" 

df = ts109.query(qry)
df = ts109.clean(df)
df.head(20)
# Out:
#                   p                                                  o
# 0              type                                    major_Aerodrome
# 1              type                                    AerodromeClassA
# 2       hasGeometry           geom_8.571822869076076_50.05067708952074
# 3     partOfCountry                                      Place_Germany
# 4  elevationOfPlace                                 110.94720000000001
# 5    hasCountryCode                                                 DE
# 6      hasPlaceName  Flughafen Frankfurt Åm Main, Walldorf, Hesse, ...
# 7           seeAlso      http://worldaerodata.com/wad.cgi?airport=EDDF
# 8           seeAlso              http://www.airportcity-frankfurt.com/
# 9           seeAlso     http://en.wikipedia.org/wiki/Frankfurt_Airport

# %% [markdown]
# # Weather Analysis (related to page 5 of tutorial)
#
# I think I will need some help here too!
#
# Though we have seen that Sectors and Participants cannot be linked with other objects, I can infer from the semantics of the regulations that the airports EDDF and LEBL and the airspace LECB must have had severe wx at that time.
#
# Lets try to pull it out.
#
# To my knowledge, the wx is written to the nodes, so I need to find the trajectories which have a spatio-temporal intersection with the wx event at the sector. For this, I begin with the basic intersection query from the tutorial, page 5.

# %%
# PREFIX bif: <java:datAcronTester.unipi.gr.sparql_functions.>   <--- only to be used in 109

qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?vessel ?time ?wkt ?speed  
WHERE {
# ?s1   a :Node ;
        :ofMovingObject ?vessel ;
        :hasSpeed ?speed ;
     dul:hasConstituent/:TimeStart ?time ;
     dul:hasConstituent/:hasWKT ?wkt .

FILTER(bif:st_distance(bif:st_geomfromtext ("POINT(13.139045 44.466133)"),bif:st_geomfromtext(?wkt))<=5)
}
"""

df = ts107.query(qry)
df = ts107.clean(df)
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     570         try:
# --> 571             response = urlopener(request)
#     572             return response, self.returnFormat
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 500: SPARQL Request Failed
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-22-4faba6723360> in <module>()
#      18 """
#      19
# ---> 20 df = ts107.query(qry)
#      21 df = ts107.clean(df)
#      22 df.head(20)
#
# /home/joerg/jsnotes/1_datAcron/datacron_connector.py in query(self, query)
#      46
#      47
# ---> 48         result = self.sparql.query().convert()
#      49
#      50         #clean up the column mess (thanks to David Knodt)
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#     599             @rtype: L{QueryResult} instance
#     600         """
# --> 601         return QueryResult(self._query())
#     602
#     603     def queryAndConvert(self):
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     577                 raise EndPointNotFound(e.read())
#     578             elif e.code == 500:
# --> 579                 raise EndPointInternalError(e.read())
#     580             else:
#     581                 raise e
#
# EndPointInternalError: EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Virtuoso S1T00 Error SR171: Transaction timed out\n\nSPARQL query:\ndefine sql:big-data-const 0 \n#output-format:application/sparql-results+json\n\nPREFIX : <http://www.datacron-project.eu/datAcron#>\nPREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\n\nSELECT ?vessel ?time ?wkt ?speed  \nWHERE {\n?s1   a :Node ;\n        :ofMovingObject ?vessel ;\n        :hasSpeed ?speed ;\n     dul:hasConstituent/:TimeStart ?time ;\n     dul:hasConstituent/:hasWKT ?wkt .\n\nFILTER(bif:st_distance(bif:st_geomfromtext ("POINT(13.139045 44.466133)"),bif:st_geomfromtext(?wkt))<=5)\n}\n'

# %% [markdown]
# PROBLEMS
#  - I get a timeout on the 107 store
#  - I get zero results on the 109 store
#  - note: on the 107 store, the bif: prefix must not be used, on the 109 store, it must be used. Therefore, you cannot query both stores with the same string atm.
#
#
# Back to EDDF and LEBL and LECB. Our goal is to get some weather for these places at regulation time.
#
# As a first step, we get the geometries of the _reference locations_.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>

SELECT DISTINCT ?airport ?iata ?placename ?geo ?o
WHERE {
  VALUES ?airport {'EDDF' 'LEBL' 'LECB'}
  # ?s :hasICAOcode ?airport ;
     :hasIATAcode ?iata ;
     :hasPlaceName ?placename ;
     :hasGeometry ?geo .
  # ?geo :hasMBR_WKT ?o .
     
}
"""

reflocs_manually = ts107.query(qry)
reflocs_manually = ts107.clean(reflocs_manually)
reflocs_manually.head(20)
# Out:
#   airport iata          placename                                        geo  \
# 0    LEBL  BCN  BARCELONA/EL PRAT  geom_2_0783333778381348_41_29694366455078
# 1    EDDF  FRA     FRANKFURT MAIN   geom_8_570555686950684_50_03333282470703
#
#                                               o
# 0  POINT (2.0783333778381348 41.29694366455078)
# 1   POINT (8.570555686950684 50.03333282470703)

# %% [markdown]
# INFO
#
# For the above query, once again, the 109 yields no results.
#
#
# Next step: lets get time and position of Frankfurt airport and try to find some spatio-temporal intersecting trajectories.

# %%
time = reguls.iloc[0]['start']     #get the time of EDDF regulation
rpoint = reflocs_manually.iloc[0]['o'] #get the coordinates of Frankfurt airport (manually)

print(time)
print(rpoint)
# Out:
# 2016-04-01T04:40:00
# POINT (2.0783333778381348 41.29694366455078)

# %% [markdown]
# In the next query, I have to enter the times manually, because (as we have seen) the end time of a regulation is not available in the system. AFAIK, the nodes themselves only have start times, as they only represent a point in time.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?vessel ?time ?wkt ?speed 
WHERE {
    # ?s1     a              :Node ;
           :ofMovingObject ?vessel ;
           :hasSpeed       ?speed ;
        dul:hasConstituent/:TimeStart ?time ;
        dul:hasConstituent/:hasWKT ?wkt .
        
    FILTER(bif:st_distance( bif:st_geomfromtext ('""" + rpoint + """'), bif:st_geomfromtext(?wkt)) <= 5 &&
    xsd:dateTime(substr(?time,1,19))>xsd:dateTime("2016-04-01 04:40:00") && 
    xsd:dateTime(substr(?time,1,19))<xsd:dateTime("2016-04-01 06:52:00"))
}
"""

df = ts107.query(qry)
df = ts107.clean(df)
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     570         try:
# --> 571             response = urlopener(request)
#     572             return response, self.returnFormat
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 500: SPARQL Request Failed
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-28-96c9f257e171> in <module>()
#      19 """
#      20
# ---> 21 df = ts107.query(qry)
#      22 df = ts107.clean(df)
#      23 df.head(20)
#
# /home/joerg/jsnotes/1_datAcron/datacron_connector.py in query(self, query)
#      46
#      47
# ---> 48         result = self.sparql.query().convert()
#      49
#      50         #clean up the column mess (thanks to David Knodt)
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#     599             @rtype: L{QueryResult} instance
#     600         """
# --> 601         return QueryResult(self._query())
#     602
#     603     def queryAndConvert(self):
#
# /home/joerg/anaconda3/envs/datacron1/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     577                 raise EndPointNotFound(e.read())
#     578             elif e.code == 500:
# --> 579                 raise EndPointInternalError(e.read())
#     580             else:
#     581                 raise e
#
# EndPointInternalError: EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Virtuoso S1T00 Error SR171: Transaction timed out\n\nSPARQL query:\ndefine sql:big-data-const 0 \n#output-format:application/sparql-results+json\n\nPREFIX : <http://www.datacron-project.eu/datAcron#>\nPREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\n\nSELECT ?vessel ?time ?wkt ?speed \nWHERE {\n    ?s1     a              :Node ;\n           :ofMovingObject ?vessel ;\n           :hasSpeed       ?speed ;\n        dul:hasConstituent/:TimeStart ?time ;\n        dul:hasConstituent/:hasWKT ?wkt .\n        \n    FILTER(bif:st_distance( bif:st_geomfromtext (\'POINT (2.0783333778381348 41.29694366455078)\'), bif:st_geomfromtext(?wkt)) <= 5 &&\n    xsd:dateTime(substr(?time,1,19))>xsd:dateTime("2016-04-01 04:40:00") && \n    xsd:dateTime(substr(?time,1,19))<xsd:dateTime("2016-04-01 06:52:00"))\n}\n'

# %% [markdown]
# PROBLEM
#
#  - According to this query, no trajectory intersects with EDDF.... I think this must be a query problem.
#  - on the 107 store, this transaction times out.
#
#
#
# Lets go on and check if wx conditions are available in the system.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX sw: <http://sweet.jpl.nasa.gov>

SELECT ?s ?w
WHERE {
    # ?s a             :Node ;
       :hasWeatherCondition ?w .
    
    FILTER regex(str(?s), 'm3', "i")
}
"""

df = ts109.query(qry)
df = ts109.clean(df)
df.head(5)
# Out:
# Empty DataFrame
# Columns: [s, w]
# Index: []

# %% [markdown]
# LITTLE PROBLEM
#
# Only in the 107 data store, I get results.

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX sw: <http://sweet.jpl.nasa.gov>

SELECT ?s ?p 
WHERE {
    # ?s ?p :LEBLA01M_411
}
"""

df = ts109.query(qry)
df = ts109.clean(df)
df.head(5)
# Out:
#                                    s           p
# 0  traj_AA51136207_20160401082500_m2  affectedBy
# 1  traj_AA51134958_20160401101500_m2  affectedBy
# 2  traj_AA51143112_20160401090500_m2  affectedBy
# 3  traj_AA51142022_20160401064000_m2  affectedBy
# 4  traj_AA51144491_20160401080500_m2  affectedBy

# %%
df = ts109.qry_properties(':LEBLA01M_411', True)

df
# Out:
#                        p                                 o
# 0                   type             ATC_WeatherRegulation
# 1              hasRegion                 Airspace_LEBL_411
# 2        hasTimeInterval  intv_1459490400000_1459515600000
# 3   RegulationAiracCycle                               411
# 4  RegulationDescription                       CB + STORM_
# 5   hasReferenceLocation   Place_Barcelona_El_Prat_Airport
