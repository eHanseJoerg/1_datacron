# %% [markdown]
# The goal of this notebook is to prove and visualize Jörg's theorem:
#
# > For a specific sector, the locations of bad WX are almost always self or the nearby major airport.
#
# The corollary of this theorem is that we just need to observe the WX of the sector itself and the WX of its "reference location" to predict if a regulation is needed for this sector or not.
# We do this with a step by step approach:
#
#  - Pull allspanishairblocks.csv. Reconstruct sectors from airblock geometries.
#  - GeoJSONify the coordinates and visualize the airblocks
#  - Find the center of each sector
#  - Pull regulations.csv. For each regulation, draw a line from the regulation.sector.center to the regulation.referenceLocation.coordinate
#
# This shall prove visually that there are no two lines from a sector center to reference locations. Raw data checking in the triple store showed that this happened only once in German airspace.

# %% [markdown]
# ## Helper functions

# %%
import pandas as pd
import json
import folium
from geomet import wkt
from pandas.io.json import json_normalize, read_json
from SPARQLWrapper import SPARQLWrapper, JSON, XML, RDF

#import my connection module which allows to connect to the datAcron rdf store
from datacron_connector import TripleStoreConnector
ts107 = TripleStoreConnector(0)
ts109 = TripleStoreConnector(1)


def wkt_to_geojson(dataframe, wkt_column_name, geojson_column_name):
    """
    Gets a pandas.DataFrame and converts a WKT column into a GeoJSON column.
    The GeoJSON column then contains a dict.
    
    Keyword arguments:
    dataframe -- the pandas.DataFrame which should be altered
    wkt_column_name -- the name of the column containing the well-known-text
    geojson_column_name -- how the GeoJSON column shall be named
    
    """
    if type(dataframe) != pd.core.frame.DataFrame:
        raise TypeError('The parameter dataframe must be a Pandas DataFrame.')
    if not wkt_column_name in dataframe.columns:
        raise ValueError('No column with the specified name found in the DataFrame')
    
    dataframe[geojson_column_name] = dataframe[wkt_column_name].apply(lambda x: wkt.loads(x))
    return dataframe

# to check if a polygon is convex
def zCrossProduct(a,b,c):
   return (a[0]-b[0])*(b[1]-c[1])-(a[1]-b[1])*(b[0]-c[0])

def isConvex(vertices):
    if len(vertices)<4:
        return True
    signs= [zCrossProduct(a,b,c)>0 for a,b,c in zip(vertices[2:],vertices[1:],vertices)]
    return all(signs) or not any(signs)

# %% [markdown]
# ## Pull allspanishairblocks.csv and reconstruct sectors from airblock geometries

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>

SELECT  ?config ?bigairspace ?airspace ?block ?start ?end ?wkt ?lowerlevel ?upperlevel
WHERE { 
   
   # get blocks:
   # ?airspace dul:hasPart       ?block .
   # ?block       :hasLowerLevel ?lowerlevel ;
                :hasUpperLevel ?upperlevel ;
                :hasGeometry   ?geom.
   # ?geom        :hasMBR_WKT    ?wkt .
   
   # get active config times for all these blocks:
   # ?bigairspace dul:hasPart ?airspace.   
   # ?config      a              :FM_Configuration ;
                :hasCapacity   ?capacity ;
                :configurationOfAirspace ?bigairspace ;
             dul:hasConstituent          ?period .
   # ?period      :TimeStart               ?start ;
                :TimeEnd                 ?end.
   
   
   #filter for only spanish airblocks:
   FILTER regex(str(?block), 'Airblock_LE', "i")
   
}
"""

open_airblocks = ts109.query(qry)
open_airblocks = ts109.clean(open_airblocks)
open_airblocks = open_airblocks.sort_values('block')

open_airblocks.to_csv('data/opening_times_of_airblocks_squares.csv')
print(len(open_airblocks))
open_airblocks.iloc[15:].head(5)
# Out:
# 106741
#                                      config           bigairspace  \
# 6238  AirspaceConfiguration_LEBLTMA_5AW_411  Airspace_LEBLTMA_411
# 6239  AirspaceConfiguration_LEBLTMA_5AW_411  Airspace_LEBLTMA_411
# 6660  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
# 6661  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
# 6662  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
#
#                   airspace                   block                start  \
# 6238  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-13T20:30:00
# 6239  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-15T20:30:00
# 6660  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-05T20:30:00
# 6661  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-08T05:00:00
# 6662  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-19T20:30:00
#
#                       end                                                wkt  \
# 6238  2016-04-13T20:59:00  POLYGON ((1.85638888888889 41.4630555555556, 1...
# 6239  2016-04-15T20:59:00  POLYGON ((1.85638888888889 41.4630555555556, 1...
# 6660  2016-04-05T20:59:00  POLYGON ((1.85638888888889 41.4630555555556, 1...
# 6661  2016-04-08T05:29:00  POLYGON ((1.85638888888889 41.4630555555556, 1...
# 6662  2016-04-19T20:32:00  POLYGON ((1.85638888888889 41.4630555555556, 1...
#
#      lowerlevel upperlevel
# 6238        0.0     5943.6
# 6239        0.0     5943.6
# 6660        0.0     5943.6
# 6661        0.0     5943.6
# 6662        0.0     5943.6

# %%
# Einlesen der airblock - Koordinaten
airblocks = pd.read_csv('data/opening_times_of_airblocks_squares.csv')
#Konvertieren zu Sektoren und GeoJSON
sectors = airblocks[['airspace', 'block', 'wkt', 'lowerlevel', 'upperlevel']]
sectors = sectors.drop_duplicates()
sectors = wkt_to_geojson(sectors, wkt_column_name='wkt', geojson_column_name='geojson')
sectors.to_csv('data/geojsontest.csv')
print(len(sectors))
sectors.head(5)

# %% [markdown]
# Now we want to construct a visualization of all sectors, comprised of airblock, in spain. We start with a simple thing: just visualizing the first 100 airblocks at once, without fusioning them.

# %%
import folium
spainmap = folium.Map(location=[35, 5], zoom_start=3, control_scale=True, prefer_canvas=True)
#spainmap.choropleth(geo_str=str(spain))
#spainmap.save(outfile='maps/mapspain.html')
#mapspain
for index, row in sectors.head(100).iterrows():
    c = folium.GeoJson(row['geojson'], name=row['block'], overlay=True,
                       style_function = lambda feature: {'fillColor': '#ffaf00','color': 'blue', 'weight': 2.5,'dashArray': '5, 5'}, 
                       highlight_function = lambda feature: {'fillColor': '#ffaf00','color': 'green', 'weight': 5,'dashArray': '5, 5'})          
    c.add_child(folium.Popup(row['airspace'] + '\n' + row['block']))
    c.add_to(spainmap)

    
folium.LayerControl().add_to(spainmap)
spainmap.save(outfile='maps/spainmap.html')
spainmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Hmmm it seems like there was some simplification going on in the loading of the airblock coordinates into the triple store.
#
# According to Giorgos, I have to take care about the way of querying the data:
# If you try:
# PREFIX : <http://www.datacron-project.eu/datAcron#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
# PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT  * WHERE {
# ?s :hasMBR_WKT ?mbr
# } LIMIT 10
#
# you get the MBR. If you try:
#
# PREFIX : <http://www.datacron-project.eu/datAcron#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
# PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?s (myfn:getGeom(?s) as ?actualGeom) WHERE {
# ?s :hasMBR_WKT ?mbr
# } LIMIT 10
#
# you get the WKT of the actual geometry :) .
#
# Kind regards,
# Giorgos
#
#
# So we can construct the airblocks with a slightly different query:

# %%
qry = """
PREFIX : <http://www.datacron-project.eu/datAcron#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX myfn: <java:datAcronTester.unipi.gr.sparql_functions.>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT  ?config ?bigairspace ?airspace ?block ?start ?end ?geom (myfn:getGeom(?geom) as ?actualGeom) ?lowerlevel ?upperlevel
WHERE { 
   
   # get blocks:
   # ?airspace dul:hasPart       ?block .
   # ?block       :hasLowerLevel ?lowerlevel ;
                :hasUpperLevel ?upperlevel ;
                :hasGeometry   ?geom.
   # ?geom        :hasMBR_WKT    ?wkt .
   
   # get active config times for all these blocks:
   # ?bigairspace dul:hasPart ?airspace.   
   # ?config      a              :FM_Configuration ;
                :hasCapacity   ?capacity ;
                :configurationOfAirspace ?bigairspace ;
             dul:hasConstituent          ?period .
   # ?period      :TimeStart               ?start ;
                :TimeEnd                 ?end.
   
   
   #filter for only spanish airblocks:
   FILTER regex(str(?block), 'Airblock_LE', "i")
   
}
"""

open_airblocks = ts109.query(qry)
open_airblocks = ts109.clean(open_airblocks)
open_airblocks = open_airblocks.sort_values('block')

open_airblocks.to_csv('data/opening_times_of_airblocks_exact.csv')
print(len(open_airblocks))
open_airblocks.iloc[15:].head(5)
# Out:
# 106741
#                                      config           bigairspace  \
# 6238  AirspaceConfiguration_LEBLTMA_5AW_411  Airspace_LEBLTMA_411
# 6239  AirspaceConfiguration_LEBLTMA_5AW_411  Airspace_LEBLTMA_411
# 6660  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
# 6661  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
# 6662  AirspaceConfiguration_LEBLTMA_5BE_411  Airspace_LEBLTMA_411
#
#                   airspace                   block                start  \
# 6238  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-13T20:30:00
# 6239  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-15T20:30:00
# 6660  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-05T20:30:00
# 6661  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-08T05:00:00
# 6662  Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE  2016-04-19T20:30:00
#
#                       end                                              geom  \
# 6238  2016-04-13T20:59:00  http://83.212.239.107/geometries/airblocks/053LE
# 6239  2016-04-15T20:59:00  http://83.212.239.107/geometries/airblocks/053LE
# 6660  2016-04-05T20:59:00  http://83.212.239.107/geometries/airblocks/053LE
# 6661  2016-04-08T05:29:00  http://83.212.239.107/geometries/airblocks/053LE
# 6662  2016-04-19T20:32:00  http://83.212.239.107/geometries/airblocks/053LE
#
#                                              actualGeom lowerlevel upperlevel
# 6238  POLYGON ((1.85638888888889 41.7558333333333, 2...        0.0     5943.6
# 6239  POLYGON ((1.85638888888889 41.7558333333333, 2...        0.0     5943.6
# 6660  POLYGON ((1.85638888888889 41.7558333333333, 2...        0.0     5943.6
# 6661  POLYGON ((1.85638888888889 41.7558333333333, 2...        0.0     5943.6
# 6662  POLYGON ((1.85638888888889 41.7558333333333, 2...        0.0     5943.6

# %%
# Einlesen der airblock - Koordinaten
airblocks = pd.read_csv('data/opening_times_of_airblocks_exact.csv')
#Konvertieren zu Sektoren und GeoJSON
sectorsexact = airblocks[['airspace', 'block', 'actualGeom', 'lowerlevel', 'upperlevel']]
sectorsexact = sectorsexact.drop_duplicates()
sectorsexact = wkt_to_geojson(sectorsexact, wkt_column_name='actualGeom', geojson_column_name='geojson')
sectorsexact.to_csv('data/geojsontestexact.csv')
print(len(sectorsexact))
sectorsexact.head(5)
# Out:
# 358
#                   airspace                   block  \
# 0     Airspace_LEBLBL1_411  Airblock_LEBLBL1_053LE
# 436   Airspace_LEBLBL1_411  Airblock_LEBLBL1_054LE
# 872   Airspace_LEBLBL1_411  Airblock_LEBLBL1_073LE
# 1308  Airspace_LEBLBL1_411  Airblock_LEBLBL1_076LE
# 1744  Airspace_LEBLBL2_411  Airblock_LEBLBL2_065LE
#
#                                              actualGeom  lowerlevel  \
# 0     POLYGON ((1.85638888888889 41.7558333333333, 2...         0.0
# 436   POLYGON ((2.50638888888889 41.9577777777778, 2...      2590.8
# 872   POLYGON ((1.88277777777778 41.6066666666667, 2...      3200.4
# 1308  POLYGON ((2.09777777777778 41.2966666666667, 2...      1981.2
# 1744  POLYGON ((2.5675 41.4630555555556, 2.579166666...      1981.2
#
#       upperlevel                                            geojson
# 0         5943.6  {'type': 'Polygon', 'coordinates': [[[1.856388...
# 436       5943.6  {'type': 'Polygon', 'coordinates': [[[2.506388...
# 872       5943.6  {'type': 'Polygon', 'coordinates': [[[1.882777...
# 1308      5943.6  {'type': 'Polygon', 'coordinates': [[[2.097777...
# 1744      5943.6  {'type': 'Polygon', 'coordinates': [[[2.5675, ...

# %%
import folium
spainmap2 = folium.Map(location=[35, 5], zoom_start=3, control_scale=True, prefer_canvas=True)
#spainmap.choropleth(geo_str=str(spain))
#spainmap.save(outfile='maps/mapspain.html')
#mapspain
for index, row in sectorsexact.head(100).iterrows():
    c = folium.GeoJson(row['geojson'], name=row['block'], overlay=True,
                       style_function = lambda feature: {'fillColor': '#ffaf00','color': 'blue', 'weight': 2.5,'dashArray': '5, 5'}, 
                       highlight_function = lambda feature: {'fillColor': '#ffaf00','color': 'green', 'weight': 5,'dashArray': '5, 5'})          
    c.add_child(folium.Popup(row['airspace'] + '\n' + row['block']))
    c.add_to(spainmap2)

    
folium.LayerControl().add_to(spainmap2)
spainmap2.save(outfile='maps/spainmap2.html')
spainmap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Old Stuff

# %%
raw = 'POLYGON ((1.85638888888889 41.7558333333333, 2.52833333333333 41.8480555555556, 2.55888888888889 41.81, 2.61916666666667 41.7666666666667, 2.63972222222222 41.7572222222222, 2.84083333333333 41.6713888888889, 2.5675 41.4630555555556, 2.54277777777778 41.4955555555556, 2.52194444444444 41.5152777777778, 2.49805555555556 41.5327777777778, 2.47138888888889 41.5480555555556, 2.44222222222222 41.5605555555556, 2.41138888888889 41.5702777777778, 2.37916666666667 41.5769444444444, 2.34611111111111 41.5805555555556, 2.3125 41.5808333333333, 2.27944444444444 41.5780555555556, 2.24666666666667 41.5722222222222, 2.21555555555556 41.5636111111111, 2.16083333333333 41.5447222222222, 2.18694444444444 41.6469444444444, 1.88277777777778 41.6066666666667, 1.85638888888889 41.7558333333333))'
tripled = 'POLYGON ((1.85638888888889 41.4630555555556, 1.85638888888889 41.8480555555556, 2.84083333333333 41.8480555555556, 2.84083333333333 41.4630555555556, 1.85638888888889 41.4630555555556))'

raw_geojson = wkt.loads(raw)
tripled_geojson = wkt.loads(tripled)


exmap = folium.Map(location=[35, 5], zoom_start=3, control_scale=True, prefer_canvas=True)

d = folium.GeoJson(raw_geojson, name='raw', overlay=True)
e = folium.GeoJson(tripled_geojson, name='tripled', overlay=True)
d.add_to(exmap)
e.add_to(exmap)
    
    
folium.LayerControl().add_to(exmap)
spainmap.save(outfile='maps/exmap.html')
exmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#For each sector, construct a multi-Polygon which is comprised of its sectors. Therefore:

#Construct a dict which maps one sector to the collection of all airblock coodinates.
sector = ''
sector_dict = {}

for  i in range(len(sectors)):
    sector = sectors.iloc[i]['airspace']
    coordi = sectors.iloc[i]['geojson']['coordinates'][0].copy()
    try:
        for elem in coordi:
            sector_dict[sector].append(elem)
    except KeyError:
        sector_dict[sector] = coordi

#re-geojsonify the constructed dict.
for key, value in sector_dict.items():
    sector_dict[key] = {"type": "Polygon", "coordinates": value}

# %%
spain = {'type': 'FeatureCollection', 'features':[]}

for i in range(len(sectors)):
    spain['features'].append({'type':'Feature', 'id': sectors.iloc[i]['block'],
                              'geometry': sectors.iloc[i]['geojson']['coordinates'] })

spain
# Out:
# {'features': [{'geometry': [[[1.85638888888889, 41.4630555555556],
#      [1.85638888888889, 41.8480555555556],
#      [2.84083333333333, 41.8480555555556],
#      [2.84083333333333, 41.4630555555556],
#      [1.85638888888889, 41.4630555555556]]],
#    'id': 'Airblock_LEBLBL1_053LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50416666666667, 41.6713888888889],
#      [2.50416666666667, 41.9577777777778],
#      [3.00638888888889, 41.9577777777778],
#      [3.00638888888889, 41.6713888888889],
#      [2.50416666666667, 41.6713888888889]]],
#    'id': 'Airblock_LEBLBL1_054LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.88277777777778, 41.2966666666667],
#      [1.88277777777778, 41.6469444444444],
#      [2.18694444444444, 41.6469444444444],
#      [2.18694444444444, 41.2966666666667],
#      [1.88277777777778, 41.2966666666667]]],
#    'id': 'Airblock_LEBLBL1_073LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.09777777777778, 41.2966666666667],
#      [2.09777777777778, 41.5808333333333],
#      [2.5675, 41.5808333333333],
#      [2.5675, 41.2966666666667],
#      [2.09777777777778, 41.2966666666667]]],
#    'id': 'Airblock_LEBLBL1_076LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.09777777777778, 41.1325],
#      [2.09777777777778, 41.4630555555556],
#      [2.59027777777778, 41.4630555555556],
#      [2.59027777777778, 41.1325],
#      [2.09777777777778, 41.1325]]],
#    'id': 'Airblock_LEBLBL2_065LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.616666666666667, 41.1166666666667],
#      [-0.616666666666667, 42.1],
#      [0.216666666666667, 42.1],
#      [0.216666666666667, 41.1166666666667],
#      [-0.616666666666667, 41.1166666666667]]],
#    'id': 'Airblock_LEBLDDN_456LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.291666666666667, 41.2333333333333],
#      [-0.291666666666667, 42.85],
#      [0.733333333333333, 42.85],
#      [0.733333333333333, 41.2333333333333],
#      [-0.291666666666667, 41.2333333333333]]],
#    'id': 'Airblock_LEBLDDN_457LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.925555555555556, 39.7338888888889],
#      [-0.925555555555556, 41.2533333333333],
#      [1.32805555555556, 41.2533333333333],
#      [1.32805555555556, 39.7338888888889],
#      [-0.925555555555556, 39.7338888888889]]],
#    'id': 'Airblock_LEBLDDS_107LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.576944444444444, 40.5486111111111],
#      [0.576944444444444, 41.2836111111111],
#      [1.98583333333333, 41.2836111111111],
#      [1.98583333333333, 40.5486111111111],
#      [0.576944444444444, 40.5486111111111]]],
#    'id': 'Airblock_LEBLDDS_108LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.172777777777778, 39.6452777777778],
#      [0.172777777777778, 40.5677777777778],
#      [1.85333333333333, 40.5677777777778],
#      [1.85333333333333, 39.6452777777778],
#      [0.172777777777778, 39.6452777777778]]],
#    'id': 'Airblock_LEBLDDS_109LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.32805555555556, 40.0811111111111],
#      [1.32805555555556, 40.9988888888889],
#      [2.10888888888889, 40.9988888888889],
#      [2.10888888888889, 40.0811111111111],
#      [1.32805555555556, 40.0811111111111]]],
#    'id': 'Airblock_LEBLDDS_110LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.07083333333333, 40.8752777777778],
#      [2.07083333333333, 41.2966666666667],
#      [2.36944444444444, 41.2966666666667],
#      [2.36944444444444, 40.8752777777778],
#      [2.07083333333333, 40.8752777777778]]],
#    'id': 'Airblock_LEBLGARI_071LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.13777777777778, 41.1880555555556],
#      [1.13777777777778, 41.3483333333333],
#      [1.43083333333333, 41.3483333333333],
#      [1.43083333333333, 41.1880555555556],
#      [1.13777777777778, 41.1880555555556]]],
#    'id': 'Airblock_LEBLGONA_061LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.559444444444444, 41.2491666666667],
#      [0.559444444444444, 41.3483333333333],
#      [1.15444444444444, 41.3483333333333],
#      [1.15444444444444, 41.2491666666667],
#      [0.559444444444444, 41.2491666666667]]],
#    'id': 'Airblock_LEBLGONA_062LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.15444444444444, 40.9511111111111],
#      [1.15444444444444, 41.2491666666667],
#      [1.43583333333333, 41.2491666666667],
#      [1.43583333333333, 40.9511111111111],
#      [1.15444444444444, 40.9511111111111]]],
#    'id': 'Airblock_LEBLGONA_067LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50638888888889, 41.7966666666667],
#      [2.50638888888889, 42.4802777777778],
#      [3.39416666666667, 42.4802777777778],
#      [3.39416666666667, 41.7966666666667],
#      [2.50638888888889, 41.7966666666667]]],
#    'id': 'Airblock_LEBLGR1_055LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50416666666667, 41.7311111111111],
#      [2.50416666666667, 41.9577777777778],
#      [3.00638888888889, 41.9577777777778],
#      [3.00638888888889, 41.7311111111111],
#      [2.50416666666667, 41.7311111111111]]],
#    'id': 'Airblock_LEBLGR1_057LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.61916666666667, 41.6713888888889],
#      [2.61916666666667, 41.7966666666667],
#      [3.00638888888889, 41.7966666666667],
#      [3.00638888888889, 41.6713888888889],
#      [2.61916666666667, 41.6713888888889]]],
#    'id': 'Airblock_LEBLGR1_058LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.52305555555556, 42.0733333333333],
#      [2.52305555555556, 42.4658333333333],
#      [2.91583333333333, 42.4658333333333],
#      [2.91583333333333, 42.0733333333333],
#      [2.52305555555556, 42.0733333333333]]],
#    'id': 'Airblock_LEBLGR1_074LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.84083333333333, 41.4472222222222],
#      [2.84083333333333, 41.8336111111111],
#      [3.38472222222222, 41.8336111111111],
#      [3.38472222222222, 41.4472222222222],
#      [2.84083333333333, 41.4472222222222]]],
#    'id': 'Airblock_LEBLGR2_064LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50638888888889, 41.7966666666667],
#      [2.50638888888889, 42.4802777777778],
#      [3.39416666666667, 42.4802777777778],
#      [3.39416666666667, 41.7966666666667],
#      [2.50638888888889, 41.7966666666667]]],
#    'id': 'Airblock_LEBLGR3_055LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.16666666666667, 42.0255555555556],
#      [3.16666666666667, 42.4333333333333],
#      [3.39416666666667, 42.4333333333333],
#      [3.39416666666667, 42.0255555555556],
#      [3.16666666666667, 42.0255555555556]]],
#    'id': 'Airblock_LEBLGR3_436LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.37555555555556, 41.8336111111111],
#      [3.37555555555556, 42.3747222222222],
#      [4.0375, 42.3747222222222],
#      [4.0375, 41.8336111111111],
#      [3.37555555555556, 41.8336111111111]]],
#    'id': 'Airblock_LEBLGR3_437LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.278333333333333, 41.1255555555556],
#      [0.278333333333333, 42.85],
#      [1.97083333333333, 42.85],
#      [1.97083333333333, 41.1255555555556],
#      [0.278333333333333, 41.1255555555556]]],
#    'id': 'Airblock_LEBLNW4_060LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.13777777777778, 41.1880555555556],
#      [1.13777777777778, 41.3483333333333],
#      [1.43083333333333, 41.3483333333333],
#      [1.43083333333333, 41.1880555555556],
#      [1.13777777777778, 41.1880555555556]]],
#    'id': 'Airblock_LEBLNW4_061LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.559444444444444, 41.2491666666667],
#      [0.559444444444444, 41.3483333333333],
#      [1.15444444444444, 41.3483333333333],
#      [1.15444444444444, 41.2491666666667],
#      [0.559444444444444, 41.2491666666667]]],
#    'id': 'Airblock_LEBLNW4_062LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.15444444444444, 40.9511111111111],
#      [1.15444444444444, 41.2491666666667],
#      [1.43583333333333, 41.2491666666667],
#      [1.43583333333333, 40.9511111111111],
#      [1.15444444444444, 40.9511111111111]]],
#    'id': 'Airblock_LEBLSW3_067LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.58111111111111, 41.0086111111111],
#      [1.58111111111111, 41.3111111111111],
#      [2.09777777777778, 41.3111111111111],
#      [2.09777777777778, 41.0086111111111],
#      [1.58111111111111, 41.0086111111111]]],
#    'id': 'Airblock_LEBLSW3_068LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.719444444444444, 40.0811111111111],
#      [0.719444444444444, 41.1880555555556],
#      [2.10888888888889, 41.1880555555556],
#      [2.10888888888889, 40.0811111111111],
#      [0.719444444444444, 40.0811111111111]]],
#    'id': 'Airblock_LEBLSW3_069LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50638888888889, 41.7966666666667],
#      [2.50638888888889, 42.4802777777778],
#      [3.39416666666667, 42.4802777777778],
#      [3.39416666666667, 41.7966666666667],
#      [2.50638888888889, 41.7966666666667]]],
#    'id': 'Airblock_LEBLXAR_055LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.72805555555556, 41.7558333333333],
#      [1.72805555555556, 42.5044444444444],
#      [2.91583333333333, 42.5044444444444],
#      [2.91583333333333, 41.7558333333333],
#      [1.72805555555556, 41.7558333333333]]],
#    'id': 'Airblock_LEBLXAR_430LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.85638888888889, 41.0883333333333],
#      [1.85638888888889, 41.9577777777778],
#      [3.38472222222222, 41.9577777777778],
#      [3.38472222222222, 41.0883333333333],
#      [1.85638888888889, 41.0883333333333]]],
#    'id': 'Airblock_LEBLXAR_431LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.31972222222222, 41.0172222222222],
#      [3.31972222222222, 42.1972222222222],
#      [4.43472222222222, 42.1972222222222],
#      [4.43472222222222, 41.0172222222222],
#      [3.31972222222222, 41.0172222222222]]],
#    'id': 'Airblock_LEBLXAR_432LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.95027777777778, 40.6530555555556],
#      [1.95027777777778, 41.2055555555556],
#      [3.31972222222222, 41.2055555555556],
#      [3.31972222222222, 40.6530555555556],
#      [1.95027777777778, 40.6530555555556]]],
#    'id': 'Airblock_LEBLXAR_433LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.91444444444444, 40.5],
#      [2.91444444444444, 40.9872222222222],
#      [3.99194444444444, 40.9872222222222],
#      [3.99194444444444, 40.5],
#      [2.91444444444444, 40.5]]],
#    'id': 'Airblock_LEBLXAR_434LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.18083333333333, 40.5],
#      [3.18083333333333, 41.0883333333333],
#      [4.07, 41.0883333333333],
#      [4.07, 40.5],
#      [3.18083333333333, 40.5]]],
#    'id': 'Airblock_LEBLXAR_435LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.88277777777778, 41.1222222222222],
#      [1.88277777777778, 41.8225],
#      [2.96277777777778, 41.8225],
#      [2.96277777777778, 41.1222222222222],
#      [1.88277777777778, 41.1222222222222]]],
#    'id': 'Airblock_LECBCCL_464LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.72805555555556, 41.6041666666667],
#      [1.72805555555556, 42.5044444444444],
#      [2.65222222222222, 42.5044444444444],
#      [2.65222222222222, 41.6041666666667],
#      [1.72805555555556, 41.6041666666667]]],
#    'id': 'Airblock_LECBCCL_465LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.04444444444444, 40.2961111111111],
#      [2.04444444444444, 40.8677777777778],
#      [2.92888888888889, 40.8677777777778],
#      [2.92888888888889, 40.2961111111111],
#      [2.04444444444444, 40.2961111111111]]],
#    'id': 'Airblock_LECBCCL_467LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.10888888888889, 40.0144444444444],
#      [2.10888888888889, 40.5],
#      [2.91444444444444, 40.5],
#      [2.91444444444444, 40.0144444444444],
#      [2.10888888888889, 40.0144444444444]]],
#    'id': 'Airblock_LECBCCL_468LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.16666666666667, 41.4883333333333],
#      [2.16666666666667, 42.4802777777778],
#      [4.00027777777778, 42.4802777777778],
#      [4.00027777777778, 41.4883333333333],
#      [2.16666666666667, 41.4883333333333]]],
#    'id': 'Airblock_LECBCCU_463LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.88277777777778, 41.1222222222222],
#      [1.88277777777778, 41.8225],
#      [2.96277777777778, 41.8225],
#      [2.96277777777778, 41.1222222222222],
#      [1.88277777777778, 41.1222222222222]]],
#    'id': 'Airblock_LECBCCU_464LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.04444444444444, 40.2961111111111],
#      [2.04444444444444, 40.8677777777778],
#      [2.92888888888889, 40.8677777777778],
#      [2.92888888888889, 40.2961111111111],
#      [2.04444444444444, 40.2961111111111]]],
#    'id': 'Airblock_LECBCCU_467LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.10888888888889, 40.0144444444444],
#      [2.10888888888889, 40.5],
#      [2.91444444444444, 40.5],
#      [2.91444444444444, 40.0144444444444],
#      [2.10888888888889, 40.0144444444444]]],
#    'id': 'Airblock_LECBCCU_468LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.64638888888889, 36.4536111111111],
#      [-1.64638888888889, 38.6086111111111],
#      [2.125, 38.6086111111111],
#      [2.125, 36.4536111111111],
#      [-1.64638888888889, 36.4536111111111]]],
#    'id': 'Airblock_LECBLAG_135LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.77222222222222, 36.8833333333333],
#      [-1.77222222222222, 39.2213888888889],
#      [1.88444444444444, 39.2213888888889],
#      [1.88444444444444, 36.8833333333333],
#      [-1.77222222222222, 36.8833333333333]]],
#    'id': 'Airblock_LECBLAG_136LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.483333333333333, 38.9252777777778],
#      [0.483333333333333, 39.7244444444444],
#      [1.9675, 39.7244444444444],
#      [1.9675, 38.9252777777778],
#      [0.483333333333333, 38.9252777777778]]],
#    'id': 'Airblock_LECBLAG_137LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.33333333333333, 38.4275],
#      [-1.33333333333333, 40.2333333333333],
#      [0.842222222222222, 40.2333333333333],
#      [0.842222222222222, 38.4275],
#      [-1.33333333333333, 38.4275]]],
#    'id': 'Airblock_LECBLVL_133LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.0247222222222222, 39.7338888888889],
#      [-0.0247222222222222, 40.7052777777778],
#      [1.07583333333333, 40.7052777777778],
#      [1.07583333333333, 39.7338888888889],
#      [-0.0247222222222222, 39.7338888888889]]],
#    'id': 'Airblock_LECBLVL_134LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.35972222222222, 38.4275],
#      [-1.35972222222222, 40.7052777777778],
#      [1.07583333333333, 40.7052777777778],
#      [1.07583333333333, 38.4275],
#      [-1.35972222222222, 38.4275]]],
#    'id': 'Airblock_LECBLVU_132LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.55, 38.2605555555556],
#      [3.55, 39.7166666666667],
#      [4.685, 39.7166666666667],
#      [4.685, 38.2605555555556],
#      [3.55, 38.2605555555556]]],
#    'id': 'Airblock_LECBMMS_097LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.55, 39.28],
#      [3.55, 40.5],
#      [4.66666666666667, 40.5],
#      [4.66666666666667, 39.28],
#      [3.55, 39.28]]],
#    'id': 'Airblock_LECBMNL_091LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.99194444444444, 40.5],
#      [3.99194444444444, 42.0688888888889],
#      [4.66666666666667, 42.0688888888889],
#      [4.66666666666667, 40.5],
#      [3.99194444444444, 40.5]]],
#    'id': 'Airblock_LECBMNL_092LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.90305555555556, 41.0172222222222],
#      [3.90305555555556, 41.7775],
#      [4.075, 41.7775],
#      [4.075, 41.0172222222222],
#      [3.90305555555556, 41.0172222222222]]],
#    'id': 'Airblock_LECBMNL_093LE',
#    'type': 'Feature'},
#   {'geometry': [[[3.81722222222222, 40.5],
#      [3.81722222222222, 41.0336111111111],
#      [4.07, 41.0336111111111],
#      [4.07, 40.5],
#      [3.81722222222222, 40.5]]],
#    'id': 'Airblock_LECBMNL_094LE',
#    'type': 'Feature'},
#   {'geometry': [[[0.629722222222222, 39.6452777777778],
#      [0.629722222222222, 40.9988888888889],
#      [2.26361111111111, 40.9988888888889],
#      [2.26361111111111, 39.6452777777778],
#      [0.629722222222222, 39.6452777777778]]],
#    'id': 'Airblock_LECBP1L_104LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.905, 40.1838888888889],
#      [2.905, 42.2091666666667],
#      [4.43472222222222, 42.2091666666667],
#      [4.43472222222222, 40.1838888888889],
#      [2.905, 40.1838888888889]]],
#    'id': 'Airblock_LECBVNI_085LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.9425, 41.0336111111111],
#      [2.9425, 42.2091666666667],
#      [4.43472222222222, 42.2091666666667],
#      [4.43472222222222, 41.0336111111111],
#      [2.9425, 41.0336111111111]]],
#    'id': 'Airblock_LECBVNI_086LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.92888888888889, 40.6558333333333],
#      [2.92888888888889, 41.1222222222222],
#      [3.90305555555556, 41.1222222222222],
#      [3.90305555555556, 40.6558333333333],
#      [2.92888888888889, 40.6558333333333]]],
#    'id': 'Airblock_LECBVNI_087LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.905, 40.1838888888889],
#      [2.905, 40.5],
#      [3.78333333333333, 40.5],
#      [3.78333333333333, 40.1838888888889],
#      [2.905, 40.1838888888889]]],
#    'id': 'Airblock_LECBVNI_088LE',
#    'type': 'Feature'},
#   {'geometry': [[[1.88444444444444, 37.7166666666667],
#      [1.88444444444444, 39.28],
#      [3.55, 39.28],
#      [3.55, 37.7166666666667],
#      [1.88444444444444, 37.7166666666667]]],
#    'id': 'Airblock_LECBVVS_083LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.0, 37.8666666666667],
#      [-2.0, 38.8608333333333],
#      [-0.320833333333333, 38.8608333333333],
#      [-0.320833333333333, 37.8666666666667],
#      [-2.0, 37.8666666666667]]],
#    'id': 'Airblock_LECLVALT_049LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.00277777777778, 38.1166666666667],
#      [-1.00277777777778, 38.3333333333333],
#      [-0.558055555555556, 38.3333333333333],
#      [-0.558055555555556, 38.1166666666667],
#      [-1.00277777777778, 38.1166666666667]]],
#    'id': 'Airblock_LECLVALT_051LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.77222222222222, 36.8833333333333],
#      [-1.77222222222222, 38.0],
#      [0.16, 38.0],
#      [0.16, 36.8833333333333],
#      [-1.77222222222222, 36.8833333333333]]],
#    'id': 'Airblock_LECLVALT_052LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.35, 37.3666666666667],
#      [-1.35, 37.9666666666667],
#      [-0.566666666666667, 37.9666666666667],
#      [-0.566666666666667, 37.3666666666667],
#      [-1.35, 37.3666666666667]]],
#    'id': 'Airblock_LECLVALT_316LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.558055555555556, 38.0],
#      [-0.558055555555556, 38.2758333333333],
#      [0.272777777777778, 38.2758333333333],
#      [0.272777777777778, 38.0],
#      [-0.558055555555556, 38.0]]],
#    'id': 'Airblock_LECLVMIT_319LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.151388888888889, 39.1361111111111],
#      [-0.151388888888889, 39.6575],
#      [0.483333333333333, 39.6575],
#      [0.483333333333333, 39.1361111111111],
#      [-0.151388888888889, 39.1361111111111]]],
#    'id': 'Airblock_LECLVSAL_326LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.188333333333333, 38.9419444444444],
#      [-0.188333333333333, 39.25],
#      [0.483333333333333, 39.25],
#      [0.483333333333333, 38.9419444444444],
#      [-0.188333333333333, 38.9419444444444]]],
#    'id': 'Airblock_LECLVSAL_327LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.0, 38.4547222222222],
#      [-2.0, 39.5666666666667],
#      [-1.1175, 39.5666666666667],
#      [-1.1175, 38.4547222222222],
#      [-2.0, 38.4547222222222]]],
#    'id': 'Airblock_LECLVSVC_044LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.925555555555556, 39.65],
#      [-0.925555555555556, 40.2333333333333],
#      [0.345833333333333, 40.2333333333333],
#      [0.345833333333333, 39.65],
#      [-0.925555555555556, 39.65]]],
#    'id': 'Airblock_LECLVSVC_324LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.65, 38.9675],
#      [-1.65, 40.2308333333333],
#      [-0.1, 40.2308333333333],
#      [-0.1, 38.9675],
#      [-1.65, 38.9675]]],
#    'id': 'Airblock_LECLVSVC_325LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.925555555555556, 39.65],
#      [-0.925555555555556, 40.2333333333333],
#      [0.345833333333333, 40.2333333333333],
#      [0.345833333333333, 39.65],
#      [-0.925555555555556, 39.65]]],
#    'id': 'Airblock_LECLVVLC_324LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.65, 38.9675],
#      [-1.65, 40.2308333333333],
#      [-0.1, 40.2308333333333],
#      [-0.1, 38.9675],
#      [-1.65, 38.9675]]],
#    'id': 'Airblock_LECLVVLC_325LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.151388888888889, 39.1361111111111],
#      [-0.151388888888889, 39.6575],
#      [0.483333333333333, 39.6575],
#      [0.483333333333333, 39.1361111111111],
#      [-0.151388888888889, 39.1361111111111]]],
#    'id': 'Airblock_LECLVVLC_326LE',
#    'type': 'Feature'},
#   {'geometry': [[[-0.188333333333333, 38.9419444444444],
#      [-0.188333333333333, 39.25],
#      [0.483333333333333, 39.25],
#      [0.483333333333333, 38.9419444444444],
#      [-0.188333333333333, 38.9419444444444]]],
#    'id': 'Airblock_LECLVVLC_327LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.11694444444444, 41.7697222222222],
#      [-7.11694444444444, 41.9416666666667],
#      [-6.49944444444444, 41.9416666666667],
#      [-6.49944444444444, 41.7697222222222],
#      [-7.11694444444444, 41.7697222222222]]],
#    'id': 'Airblock_LECMASL_001LP',
#    'type': 'Feature'},
#   {'geometry': [[[-7.44361111111111, 42.5666666666667],
#      [-7.44361111111111, 43.4302777777778],
#      [-6.67111111111111, 43.4302777777778],
#      [-6.67111111111111, 42.5666666666667],
#      [-7.44361111111111, 42.5666666666667]]],
#    'id': 'Airblock_LECMASL_160LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.77583333333333, 41.8305555555556],
#      [-7.77583333333333, 42.5666666666667],
#      [-6.625, 42.5666666666667],
#      [-6.625, 41.8305555555556],
#      [-7.77583333333333, 41.8305555555556]]],
#    'id': 'Airblock_LECMASL_201LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.67111111111111, 43.05],
#      [-6.67111111111111, 44.0544444444444],
#      [-5.31027777777778, 44.0544444444444],
#      [-5.31027777777778, 43.05],
#      [-6.67111111111111, 43.05]]],
#    'id': 'Airblock_LECMASL_221LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.14805555555556, 43.3938888888889],
#      [-6.14805555555556, 44.6222222222222],
#      [-4.23138888888889, 44.6222222222222],
#      [-4.23138888888889, 43.3938888888889],
#      [-6.14805555555556, 43.3938888888889]]],
#    'id': 'Airblock_LECMASL_260LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.35, 41.6736111111111],
#      [-7.35, 43.4302777777778],
#      [-5.98222222222222, 43.4302777777778],
#      [-5.98222222222222, 41.6736111111111],
#      [-7.35, 41.6736111111111]]],
#    'id': 'Airblock_LECMASL_261LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.33166666666667, 41.9838888888889],
#      [-6.33166666666667, 42.98],
#      [-5.25833333333333, 42.98],
#      [-5.25833333333333, 41.9838888888889],
#      [-6.33166666666667, 41.9838888888889]]],
#    'id': 'Airblock_LECMASL_262LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.0, 42.8277777777778],
#      [-6.0, 43.0741666666667],
#      [-5.77527777777778, 43.0741666666667],
#      [-5.77527777777778, 42.8277777777778],
#      [-6.0, 42.8277777777778]]],
#    'id': 'Airblock_LECMASL_269LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.78833333333333, 42.8966666666667],
#      [-5.78833333333333, 43.4041666666667],
#      [-4.945, 43.4041666666667],
#      [-4.945, 42.8966666666667],
#      [-5.78833333333333, 42.8966666666667]]],
#    'id': 'Airblock_LECMASL_270LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.51055555555556, 41.5916666666667],
#      [-7.51055555555556, 41.9363888888889],
#      [-6.37055555555556, 41.9363888888889],
#      [-6.37055555555556, 41.5916666666667],
#      [-7.51055555555556, 41.5916666666667]]],
#    'id': 'Airblock_LECMASL_550LP',
#    'type': 'Feature'},
#   {'geometry': [[[-7.11694444444444, 41.7697222222222],
#      [-7.11694444444444, 41.9416666666667],
#      [-6.49944444444444, 41.9416666666667],
#      [-6.49944444444444, 41.7697222222222],
#      [-7.11694444444444, 41.7697222222222]]],
#    'id': 'Airblock_LECMASU_001LP',
#    'type': 'Feature'},
#   {'geometry': [[[-7.77583333333333, 41.8305555555556],
#      [-7.77583333333333, 42.5666666666667],
#      [-6.625, 42.5666666666667],
#      [-6.625, 41.8305555555556],
#      [-7.77583333333333, 41.8305555555556]]],
#    'id': 'Airblock_LECMASU_201LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.67111111111111, 43.05],
#      [-6.67111111111111, 44.0544444444444],
#      [-5.31027777777778, 44.0544444444444],
#      [-5.31027777777778, 43.05],
#      [-6.67111111111111, 43.05]]],
#    'id': 'Airblock_LECMASU_221LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.14805555555556, 43.3938888888889],
#      [-6.14805555555556, 44.6222222222222],
#      [-4.23138888888889, 44.6222222222222],
#      [-4.23138888888889, 43.3938888888889],
#      [-6.14805555555556, 43.3938888888889]]],
#    'id': 'Airblock_LECMASU_260LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.35, 41.6736111111111],
#      [-7.35, 43.4302777777778],
#      [-5.98222222222222, 43.4302777777778],
#      [-5.98222222222222, 41.6736111111111],
#      [-7.35, 41.6736111111111]]],
#    'id': 'Airblock_LECMASU_261LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.33166666666667, 41.9838888888889],
#      [-6.33166666666667, 42.98],
#      [-5.25833333333333, 42.98],
#      [-5.25833333333333, 41.9838888888889],
#      [-6.33166666666667, 41.9838888888889]]],
#    'id': 'Airblock_LECMASU_262LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.0, 42.8277777777778],
#      [-6.0, 43.0741666666667],
#      [-5.77527777777778, 43.0741666666667],
#      [-5.77527777777778, 42.8277777777778],
#      [-6.0, 42.8277777777778]]],
#    'id': 'Airblock_LECMASU_269LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.78833333333333, 42.8966666666667],
#      [-5.78833333333333, 43.4041666666667],
#      [-4.945, 43.4041666666667],
#      [-4.945, 42.8966666666667],
#      [-5.78833333333333, 42.8966666666667]]],
#    'id': 'Airblock_LECMASU_270LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.51055555555556, 41.5916666666667],
#      [-7.51055555555556, 41.9363888888889],
#      [-6.37055555555556, 41.9363888888889],
#      [-6.37055555555556, 41.5916666666667],
#      [-7.51055555555556, 41.5916666666667]]],
#    'id': 'Airblock_LECMASU_550LP',
#    'type': 'Feature'},
#   {'geometry': [[[-4.33333333333333, 42.9577777777778],
#      [-4.33333333333333, 43.7666666666667],
#      [-3.31666666666667, 43.7666666666667],
#      [-3.31666666666667, 42.9577777777778],
#      [-4.33333333333333, 42.9577777777778]]],
#    'id': 'Airblock_LECMBLL_222LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.32638888888889, 42.3458333333333],
#      [-3.32638888888889, 42.8094444444444],
#      [-2.61777777777778, 42.8094444444444],
#      [-2.61777777777778, 42.3458333333333],
#      [-3.32638888888889, 42.3458333333333]]],
#    'id': 'Airblock_LECMBLL_226LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.6775, 42.3513888888889],
#      [-5.6775, 42.9655555555556],
#      [-4.83638888888889, 42.9655555555556],
#      [-4.83638888888889, 42.3513888888889],
#      [-5.6775, 42.3513888888889]]],
#    'id': 'Airblock_LECMBLL_263LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.6775, 42.3333333333333],
#      [-5.6775, 44.3758333333333],
#      [-2.16583333333333, 44.3758333333333],
#      [-2.16583333333333, 42.3333333333333],
#      [-5.6775, 42.3333333333333]]],
#    'id': 'Airblock_LECMBLL_555LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.25833333333333, 42.3333333333333],
#      [-5.25833333333333, 44.3758333333333],
#      [-2.16583333333333, 44.3758333333333],
#      [-2.16583333333333, 42.3333333333333],
#      [-5.25833333333333, 42.3333333333333]]],
#    'id': 'Airblock_LECMBLL_600LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.10555555555556, 42.8094444444444],
#      [-3.10555555555556, 43.0833333333333],
#      [-2.52972222222222, 43.0833333333333],
#      [-2.52972222222222, 42.8094444444444],
#      [-3.10555555555556, 42.8094444444444]]],
#    'id': 'Airblock_LECMBLL_601LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.44361111111111, 42.81],
#      [-3.44361111111111, 43.6833333333333],
#      [-2.315, 43.6833333333333],
#      [-2.315, 42.81],
#      [-3.44361111111111, 42.81]]],
#    'id': 'Airblock_LECMBLL_602LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.375, 42.2563888888889],
#      [-4.375, 42.7936111111111],
#      [-2.62083333333333, 42.7936111111111],
#      [-2.62083333333333, 42.2563888888889],
#      [-4.375, 42.2563888888889]]],
#    'id': 'Airblock_LECMBLL_603LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.13083333333333, 42.7936111111111],
#      [-3.13083333333333, 42.81],
#      [-2.94944444444444, 42.81],
#      [-2.94944444444444, 42.7936111111111],
#      [-3.13083333333333, 42.7936111111111]]],
#    'id': 'Airblock_LECMBLL_605LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.36638888888889, 39.0],
#      [-3.36638888888889, 41.1166666666667],
#      [-0.616666666666667, 41.1166666666667],
#      [-0.616666666666667, 39.0],
#      [-3.36638888888889, 39.0]]],
#    'id': 'Airblock_LECMCJL_215LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.20416666666667, 39.5830555555556],
#      [-3.20416666666667, 41.0333333333333],
#      [-2.15833333333333, 41.0333333333333],
#      [-2.15833333333333, 39.5830555555556],
#      [-3.20416666666667, 39.5830555555556]]],
#    'id': 'Airblock_LECMCJL_245LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.83333333333333, 39.0],
#      [-1.83333333333333, 40.0],
#      [-1.0, 40.0],
#      [-1.0, 39.0],
#      [-1.83333333333333, 39.0]]],
#    'id': 'Airblock_LECMCJL_247LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.99166666666667, 39.0],
#      [-2.99166666666667, 39.4055555555556],
#      [-1.39444444444444, 39.4055555555556],
#      [-1.39444444444444, 39.0],
#      [-2.99166666666667, 39.0]]],
#    'id': 'Airblock_LECMCJL_249LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.36638888888889, 39.0],
#      [-3.36638888888889, 41.1166666666667],
#      [-0.616666666666667, 41.1166666666667],
#      [-0.616666666666667, 39.0],
#      [-3.36638888888889, 39.0]]],
#    'id': 'Airblock_LECMCJU_215LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.20416666666667, 39.5830555555556],
#      [-3.20416666666667, 41.0333333333333],
#      [-2.15833333333333, 41.0333333333333],
#      [-2.15833333333333, 39.5830555555556],
#      [-3.20416666666667, 39.5830555555556]]],
#    'id': 'Airblock_LECMCJU_245LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.83333333333333, 39.0],
#      [-1.83333333333333, 40.0],
#      [-1.0, 40.0],
#      [-1.0, 39.0],
#      [-1.83333333333333, 39.0]]],
#    'id': 'Airblock_LECMCJU_247LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.99166666666667, 39.0],
#      [-2.99166666666667, 39.4055555555556],
#      [-1.39444444444444, 39.4055555555556],
#      [-1.39444444444444, 39.0],
#      [-2.99166666666667, 39.0]]],
#    'id': 'Airblock_LECMCJU_249LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.68694444444444, 41.2216666666667],
#      [-4.68694444444444, 42.3333333333333],
#      [-2.62444444444444, 42.3333333333333],
#      [-2.62444444444444, 41.2216666666667],
#      [-4.68694444444444, 41.2216666666667]]],
#    'id': 'Airblock_LECMDGL_211LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.32638888888889, 42.3458333333333],
#      [-3.32638888888889, 42.8094444444444],
#      [-2.61777777777778, 42.8094444444444],
#      [-2.61777777777778, 42.3458333333333],
#      [-3.32638888888889, 42.3458333333333]]],
#    'id': 'Airblock_LECMDGL_226LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.65666666666667, 41.3711111111111],
#      [-4.65666666666667, 42.1363888888889],
#      [-4.28333333333333, 42.1363888888889],
#      [-4.28333333333333, 41.3711111111111],
#      [-4.65666666666667, 41.3711111111111]]],
#    'id': 'Airblock_LECMDGL_230LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.83527777777778, 40.9330555555556],
#      [-3.83527777777778, 41.4769444444444],
#      [-2.78, 41.4769444444444],
#      [-2.78, 40.9330555555556],
#      [-3.83527777777778, 40.9330555555556]]],
#    'id': 'Airblock_LECMDGL_240LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.55277777777778, 40.995],
#      [-4.55277777777778, 41.5],
#      [-2.77555555555556, 41.5],
#      [-2.77555555555556, 40.995],
#      [-4.55277777777778, 40.995]]],
#    'id': 'Airblock_LECMDGL_264LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.375, 42.2563888888889],
#      [-4.375, 42.7936111111111],
#      [-2.62083333333333, 42.7936111111111],
#      [-2.62083333333333, 42.2563888888889],
#      [-4.375, 42.2563888888889]]],
#    'id': 'Airblock_LECMDGL_603LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.04527777777778, 40.8941666666667],
#      [-4.04527777777778, 41.0611111111111],
#      [-3.83527777777778, 41.0611111111111],
#      [-3.83527777777778, 40.8941666666667],
#      [-4.04527777777778, 40.8941666666667]]],
#    'id': 'Airblock_LECMDGL_604LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.68694444444444, 41.2216666666667],
#      [-4.68694444444444, 42.3333333333333],
#      [-2.62444444444444, 42.3333333333333],
#      [-2.62444444444444, 41.2216666666667],
#      [-4.68694444444444, 41.2216666666667]]],
#    'id': 'Airblock_LECMDGU_211LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.32638888888889, 42.3458333333333],
#      [-3.32638888888889, 42.8094444444444],
#      [-2.61777777777778, 42.8094444444444],
#      [-2.61777777777778, 42.3458333333333],
#      [-3.32638888888889, 42.3458333333333]]],
#    'id': 'Airblock_LECMDGU_226LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.65666666666667, 41.3711111111111],
#      [-4.65666666666667, 42.1363888888889],
#      [-4.28333333333333, 42.1363888888889],
#      [-4.28333333333333, 41.3711111111111],
#      [-4.65666666666667, 41.3711111111111]]],
#    'id': 'Airblock_LECMDGU_230LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.83527777777778, 40.9330555555556],
#      [-3.83527777777778, 41.4769444444444],
#      [-2.78, 41.4769444444444],
#      [-2.78, 40.9330555555556],
#      [-3.83527777777778, 40.9330555555556]]],
#    'id': 'Airblock_LECMDGU_240LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.55277777777778, 40.995],
#      [-4.55277777777778, 41.5],
#      [-2.77555555555556, 41.5],
#      [-2.77555555555556, 40.995],
#      [-4.55277777777778, 40.995]]],
#    'id': 'Airblock_LECMDGU_264LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.375, 42.2563888888889],
#      [-4.375, 42.7936111111111],
#      [-2.62083333333333, 42.7936111111111],
#      [-2.62083333333333, 42.2563888888889],
#      [-4.375, 42.2563888888889]]],
#    'id': 'Airblock_LECMDGU_603LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.315, 43.2583333333333],
#      [-2.315, 43.7194444444444],
#      [-1.78333333333333, 43.7194444444444],
#      [-1.78333333333333, 43.2583333333333],
#      [-2.315, 43.2583333333333]]],
#    'id': 'Airblock_LECMPAL_202LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.52972222222222, 42.9666666666667],
#      [-2.52972222222222, 43.4313888888889],
#      [-2.12722222222222, 43.4313888888889],
#      [-2.12722222222222, 42.9666666666667],
#      [-2.52972222222222, 42.9666666666667]]],
#    'id': 'Airblock_LECMPAL_223LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.61777777777778, 42.8038888888889],
#      [-2.61777777777778, 43.0116666666667],
#      [-2.08833333333333, 43.0116666666667],
#      [-2.08833333333333, 42.8038888888889],
#      [-2.61777777777778, 42.8038888888889]]],
#    'id': 'Airblock_LECMPAL_225LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.19305555555556, 42.3875],
#      [-2.19305555555556, 43.0777777777778],
#      [-1.49166666666667, 43.0777777777778],
#      [-1.49166666666667, 42.3875],
#      [-2.19305555555556, 42.3875]]],
#    'id': 'Airblock_LECMPAL_228LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.5, 41.0333333333333],
#      [-2.5, 42.6083333333333],
#      [-1.24583333333333, 42.6083333333333],
#      [-1.24583333333333, 41.0333333333333],
#      [-2.5, 41.0333333333333]]],
#    'id': 'Airblock_LECMPAL_234LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.84861111111111, 41.0333333333333],
#      [-2.84861111111111, 41.5],
#      [-2.36833333333333, 41.5],
#      [-2.36833333333333, 41.0333333333333],
#      [-2.84861111111111, 41.0333333333333]]],
#    'id': 'Airblock_LECMPAL_236LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.12722222222222, 42.8038888888889],
#      [-2.12722222222222, 43.5833333333333],
#      [-1.45083333333333, 43.5833333333333],
#      [-1.45083333333333, 42.8038888888889],
#      [-2.12722222222222, 42.8038888888889]]],
#    'id': 'Airblock_LECMPAL_250LE',
#    'type': 'Feature'},
#   {'geometry': [[[-1.66666666666667, 42.46],
#      [-1.66666666666667, 43.0777777777778],
#      [-0.844444444444444, 43.0777777777778],
#      [-0.844444444444444, 42.46],
#      [-1.66666666666667, 42.46]]],
#    'id': 'Airblock_LECMPAL_283LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.77555555555556, 41.5],
#      [-2.77555555555556, 42.6319444444444],
#      [-1.7825, 42.6319444444444],
#      [-1.7825, 41.5],
#      [-2.77555555555556, 41.5]]],
#    'id': 'Airblock_LECMPAL_285LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.62083333333333, 42.5280555555556],
#      [-2.62083333333333, 42.8083333333333],
#      [-2.08833333333333, 42.8083333333333],
#      [-2.08833333333333, 42.5280555555556],
#      [-2.62083333333333, 42.5280555555556]]],
#    'id': 'Airblock_LECMPAL_607LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.44361111111111, 42.5666666666667],
#      [-7.44361111111111, 43.4302777777778],
#      [-6.67111111111111, 43.4302777777778],
#      [-6.67111111111111, 42.5666666666667],
#      [-7.44361111111111, 42.5666666666667]]],
#    'id': 'Airblock_LECMSAL_160LE',
#    'type': 'Feature'},
#   {'geometry': [[[-13.0, 41.9333333333333],
#      [-13.0, 45.0],
#      [-5.625, 45.0],
#      [-5.625, 41.9333333333333],
#      [-13.0, 41.9333333333333]]],
#    'id': 'Airblock_LECMSAL_200LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.68972222222222, 43.4302777777778],
#      [-6.68972222222222, 44.0327777777778],
#      [-6.14805555555556, 44.0327777777778],
#      [-6.14805555555556, 43.4302777777778],
#      [-6.68972222222222, 43.4302777777778]]],
#    'id': 'Airblock_LECMSAL_210LE',
#    'type': 'Feature'},
#   {'geometry': [[[-9.56805555555556, 41.815],
#      [-9.56805555555556, 43.7633333333333],
#      [-7.29083333333333, 43.7633333333333],
#      [-7.29083333333333, 41.815],
#      [-9.56805555555556, 41.815]]],
#    'id': 'Airblock_LECMSAL_220LE',
#    'type': 'Feature'},
#   {'geometry': [[[-8.84361111111111, 41.815],
#      [-8.84361111111111, 42.1397222222222],
#      [-8.08111111111111, 42.1397222222222],
#      [-8.08111111111111, 41.815],
#      [-8.84361111111111, 41.815]]],
#    'id': 'Airblock_LECMSAL_552LP',
#    'type': 'Feature'},
#   {'geometry': [[[-7.44361111111111, 42.5666666666667],
#      [-7.44361111111111, 43.4302777777778],
#      [-6.67111111111111, 43.4302777777778],
#      [-6.67111111111111, 42.5666666666667],
#      [-7.44361111111111, 42.5666666666667]]],
#    'id': 'Airblock_LECMSAU_160LE',
#    'type': 'Feature'},
#   {'geometry': [[[-13.0, 41.9333333333333],
#      [-13.0, 45.0],
#      [-5.625, 45.0],
#      [-5.625, 41.9333333333333],
#      [-13.0, 41.9333333333333]]],
#    'id': 'Airblock_LECMSAU_200LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.68972222222222, 43.4302777777778],
#      [-6.68972222222222, 44.0327777777778],
#      [-6.14805555555556, 44.0327777777778],
#      [-6.14805555555556, 43.4302777777778],
#      [-6.68972222222222, 43.4302777777778]]],
#    'id': 'Airblock_LECMSAU_210LE',
#    'type': 'Feature'},
#   {'geometry': [[[-9.56805555555556, 41.815],
#      [-9.56805555555556, 43.7633333333333],
#      [-7.29083333333333, 43.7633333333333],
#      [-7.29083333333333, 41.815],
#      [-9.56805555555556, 41.815]]],
#    'id': 'Airblock_LECMSAU_220LE',
#    'type': 'Feature'},
#   {'geometry': [[[-8.84361111111111, 41.815],
#      [-8.84361111111111, 42.1397222222222],
#      [-8.08111111111111, 42.1397222222222],
#      [-8.08111111111111, 41.815],
#      [-8.84361111111111, 41.815]]],
#    'id': 'Airblock_LECMSAU_552LP',
#    'type': 'Feature'},
#   {'geometry': [[[-4.61111111111111, 39.5527777777778],
#      [-4.61111111111111, 41.3030555555556],
#      [-2.83333333333333, 41.3030555555556],
#      [-2.83333333333333, 39.5527777777778],
#      [-4.61111111111111, 39.5527777777778]]],
#    'id': 'Airblock_LECMTLL_059LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.35027777777778, 38.9997222222222],
#      [-5.35027777777778, 40.3122222222222],
#      [-3.20416666666667, 40.3122222222222],
#      [-3.20416666666667, 38.9997222222222],
#      [-5.35027777777778, 38.9997222222222]]],
#    'id': 'Airblock_LECMTLL_212LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.99444444444444, 40.2063888888889],
#      [-4.99444444444444, 40.2816666666667],
#      [-4.79833333333333, 40.2816666666667],
#      [-4.79833333333333, 40.2063888888889],
#      [-4.99444444444444, 40.2063888888889]]],
#    'id': 'Airblock_LECMTLL_268LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.61111111111111, 39.5527777777778],
#      [-4.61111111111111, 41.3030555555556],
#      [-2.83333333333333, 41.3030555555556],
#      [-2.83333333333333, 39.5527777777778],
#      [-4.61111111111111, 39.5527777777778]]],
#    'id': 'Airblock_LECMTLU_059LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.35027777777778, 38.9997222222222],
#      [-5.35027777777778, 40.3122222222222],
#      [-3.20416666666667, 40.3122222222222],
#      [-3.20416666666667, 38.9997222222222],
#      [-5.35027777777778, 38.9997222222222]]],
#    'id': 'Airblock_LECMTLU_212LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.99444444444444, 40.2063888888889],
#      [-4.99444444444444, 40.2816666666667],
#      [-4.79833333333333, 40.2816666666667],
#      [-4.79833333333333, 40.2063888888889],
#      [-4.99444444444444, 40.2063888888889]]],
#    'id': 'Airblock_LECMTLU_268LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.57416666666667, 39.0],
#      [-4.57416666666667, 39.1386111111111],
#      [-3.36638888888889, 39.1386111111111],
#      [-3.36638888888889, 39.0],
#      [-4.57416666666667, 39.0]]],
#    'id': 'Airblock_LECMTLU_302LE',
#    'type': 'Feature'},
#   {'geometry': [[[-2.27888888888889, 41.2194444444444],
#      [-2.27888888888889, 42.46],
#      [-0.291666666666667, 42.46],
#      [-0.291666666666667, 41.2194444444444],
#      [-2.27888888888889, 41.2194444444444]]],
#    'id': 'Airblock_LECMZGZ_034LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.29222222222222, 40.6],
#      [-6.29222222222222, 42.0],
#      [-4.66666666666667, 42.0],
#      [-4.66666666666667, 40.6],
#      [-6.29222222222222, 40.6]]],
#    'id': 'Airblock_LECMZML_016LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.6275, 40.2816666666667],
#      [-5.6275, 42.3513888888889],
#      [-4.375, 42.3513888888889],
#      [-4.375, 40.2816666666667],
#      [-5.6275, 40.2816666666667]]],
#    'id': 'Airblock_LECMZML_204LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.71111111111111, 38.9997222222222],
#      [-6.71111111111111, 40.2469444444444],
#      [-4.98277777777778, 40.2469444444444],
#      [-4.98277777777778, 38.9997222222222],
#      [-6.71111111111111, 38.9997222222222]]],
#    'id': 'Airblock_LECMZML_205LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.50083333333333, 39.1252777777778],
#      [-7.50083333333333, 39.6861111111111],
#      [-6.41388888888889, 39.6861111111111],
#      [-6.41388888888889, 39.1252777777778],
#      [-7.50083333333333, 39.1252777777778]]],
#    'id': 'Airblock_LECMZML_206LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.2925, 41.3711111111111],
#      [-5.2925, 42.2066666666667],
#      [-4.4325, 42.2066666666667],
#      [-4.4325, 41.3711111111111],
#      [-5.2925, 41.3711111111111]]],
#    'id': 'Airblock_LECMZML_229LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.41388888888889, 39.6861111111111],
#      [-6.41388888888889, 41.4052777777778],
#      [-4.66666666666667, 41.4052777777778],
#      [-4.66666666666667, 39.6861111111111],
#      [-6.41388888888889, 39.6861111111111]]],
#    'id': 'Airblock_LECMZML_231LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.01666666666667, 39.0],
#      [-7.01666666666667, 39.2333333333333],
#      [-6.22472222222222, 39.2333333333333],
#      [-6.22472222222222, 39.0],
#      [-7.01666666666667, 39.0]]],
#    'id': 'Airblock_LECMZML_232LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.06444444444444, 41.94],
#      [-6.06444444444444, 42.3705555555556],
#      [-4.93916666666667, 42.3705555555556],
#      [-4.93916666666667, 41.94],
#      [-6.06444444444444, 41.94]]],
#    'id': 'Airblock_LECMZML_265LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.83333333333333, 40.3994444444444],
#      [-6.83333333333333, 41.4830555555556],
#      [-6.27777777777778, 41.4830555555556],
#      [-6.27777777777778, 40.3994444444444],
#      [-6.83333333333333, 40.3994444444444]]],
#    'id': 'Airblock_LECMZML_500LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.37055555555556, 41.5833333333333],
#      [-6.37055555555556, 41.9838888888889],
#      [-5.84, 41.9838888888889],
#      [-5.84, 41.5833333333333],
#      [-6.37055555555556, 41.5833333333333]]],
#    'id': 'Airblock_LECMZML_507LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.04833333333333, 39.0],
#      [-7.04833333333333, 39.1166666666667],
#      [-6.95527777777778, 39.1166666666667],
#      [-6.95527777777778, 39.0],
#      [-7.04833333333333, 39.0]]],
#    'id': 'Airblock_LECMZML_553LP',
#    'type': 'Feature'},
#   {'geometry': [[[-6.29222222222222, 40.6],
#      [-6.29222222222222, 42.0],
#      [-4.66666666666667, 42.0],
#      [-4.66666666666667, 40.6],
#      [-6.29222222222222, 40.6]]],
#    'id': 'Airblock_LECMZMM_016LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.6275, 40.2816666666667],
#      [-5.6275, 42.3513888888889],
#      [-4.375, 42.3513888888889],
#      [-4.375, 40.2816666666667],
#      [-5.6275, 40.2816666666667]]],
#    'id': 'Airblock_LECMZMM_204LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.71111111111111, 38.9997222222222],
#      [-6.71111111111111, 40.2469444444444],
#      [-4.98277777777778, 40.2469444444444],
#      [-4.98277777777778, 38.9997222222222],
#      [-6.71111111111111, 38.9997222222222]]],
#    'id': 'Airblock_LECMZMM_205LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.2925, 41.3711111111111],
#      [-5.2925, 42.2066666666667],
#      [-4.4325, 42.2066666666667],
#      [-4.4325, 41.3711111111111],
#      [-5.2925, 41.3711111111111]]],
#    'id': 'Airblock_LECMZMM_229LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.41388888888889, 39.6861111111111],
#      [-6.41388888888889, 41.4052777777778],
#      [-4.66666666666667, 41.4052777777778],
#      [-4.66666666666667, 39.6861111111111],
#      [-6.41388888888889, 39.6861111111111]]],
#    'id': 'Airblock_LECMZMM_231LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.01666666666667, 39.0],
#      [-7.01666666666667, 39.2333333333333],
#      [-6.22472222222222, 39.2333333333333],
#      [-6.22472222222222, 39.0],
#      [-7.01666666666667, 39.0]]],
#    'id': 'Airblock_LECMZMM_232LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.06444444444444, 41.94],
#      [-6.06444444444444, 42.3705555555556],
#      [-4.93916666666667, 42.3705555555556],
#      [-4.93916666666667, 41.94],
#      [-6.06444444444444, 41.94]]],
#    'id': 'Airblock_LECMZMM_265LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.37055555555556, 41.5833333333333],
#      [-6.37055555555556, 41.9838888888889],
#      [-5.84, 41.9838888888889],
#      [-5.84, 41.5833333333333],
#      [-6.37055555555556, 41.5833333333333]]],
#    'id': 'Airblock_LECMZMM_507LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.04833333333333, 39.0],
#      [-7.04833333333333, 39.1166666666667],
#      [-6.95527777777778, 39.1166666666667],
#      [-6.95527777777778, 39.0],
#      [-7.04833333333333, 39.0]]],
#    'id': 'Airblock_LECMZMM_553LP',
#    'type': 'Feature'},
#   {'geometry': [[[-6.29222222222222, 40.6],
#      [-6.29222222222222, 42.0],
#      [-4.66666666666667, 42.0],
#      [-4.66666666666667, 40.6],
#      [-6.29222222222222, 40.6]]],
#    'id': 'Airblock_LECMZMU_016LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.6275, 40.2816666666667],
#      [-5.6275, 42.3513888888889],
#      [-4.375, 42.3513888888889],
#      [-4.375, 40.2816666666667],
#      [-5.6275, 40.2816666666667]]],
#    'id': 'Airblock_LECMZMU_204LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.71111111111111, 38.9997222222222],
#      [-6.71111111111111, 40.2469444444444],
#      [-4.98277777777778, 40.2469444444444],
#      [-4.98277777777778, 38.9997222222222],
#      [-6.71111111111111, 38.9997222222222]]],
#    'id': 'Airblock_LECMZMU_205LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.2925, 41.3711111111111],
#      [-5.2925, 42.2066666666667],
#      [-4.4325, 42.2066666666667],
#      [-4.4325, 41.3711111111111],
#      [-5.2925, 41.3711111111111]]],
#    'id': 'Airblock_LECMZMU_229LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.41388888888889, 39.6861111111111],
#      [-6.41388888888889, 41.4052777777778],
#      [-4.66666666666667, 41.4052777777778],
#      [-4.66666666666667, 39.6861111111111],
#      [-6.41388888888889, 39.6861111111111]]],
#    'id': 'Airblock_LECMZMU_231LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.01666666666667, 39.0],
#      [-7.01666666666667, 39.2333333333333],
#      [-6.22472222222222, 39.2333333333333],
#      [-6.22472222222222, 39.0],
#      [-7.01666666666667, 39.0]]],
#    'id': 'Airblock_LECMZMU_232LE',
# ...
#      [-5.58694444444444, 37.5333333333333],
#      [-5.0625, 37.5333333333333],
#      [-5.0625, 37.0144444444444],
#      [-5.58694444444444, 37.0144444444444]]],
#    'id': 'Airblock_LECSAPNN_018LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.13333333333333, 36.2361111111111],
#      [-7.13333333333333, 37.275],
#      [-5.58694444444444, 37.275],
#      [-5.58694444444444, 36.2361111111111],
#      [-7.13333333333333, 36.2361111111111]]],
#    'id': 'Airblock_LECSAPSS_013LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.25555555555556, 37.5277777777778],
#      [-4.25555555555556, 39.0],
#      [-3.1, 39.0],
#      [-3.1, 37.5277777777778],
#      [-4.25555555555556, 37.5277777777778]]],
#    'id': 'Airblock_LECSBAIL_010LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.23583333333333, 35.25],
#      [-3.23583333333333, 35.8333333333333],
#      [-2.1, 35.8333333333333],
#      [-2.1, 35.25],
#      [-3.23583333333333, 35.25]]],
#    'id': 'Airblock_LECSCARB_003GM',
#    'type': 'Feature'},
#   {'geometry': [[[-4.37083333333333, 35.8333333333333],
#      [-4.37083333333333, 36.6377777777778],
#      [-1.02361111111111, 36.6377777777778],
#      [-1.02361111111111, 35.8333333333333],
#      [-4.37083333333333, 35.8333333333333]]],
#    'id': 'Airblock_LECSCARB_009LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.11972222222222, 37.5333333333333],
#      [-5.11972222222222, 38.8038888888889],
#      [-4.30027777777778, 38.8038888888889],
#      [-4.30027777777778, 37.5333333333333],
#      [-5.11972222222222, 37.5333333333333]]],
#    'id': 'Airblock_LECSCORA_004LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.28333333333333, 37.5333333333333],
#      [-5.28333333333333, 37.9863888888889],
#      [-4.95, 37.9863888888889],
#      [-4.95, 37.5333333333333],
#      [-5.28333333333333, 37.5333333333333]]],
#    'id': 'Airblock_LECSCORA_019LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.11972222222222, 37.5333333333333],
#      [-5.11972222222222, 38.8038888888889],
#      [-4.30027777777778, 38.8038888888889],
#      [-4.30027777777778, 37.5333333333333],
#      [-5.11972222222222, 37.5333333333333]]],
#    'id': 'Airblock_LECSCORB_004LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.28333333333333, 37.5333333333333],
#      [-5.28333333333333, 37.9863888888889],
#      [-4.95, 37.9863888888889],
#      [-4.95, 37.5333333333333],
#      [-5.28333333333333, 37.5333333333333]]],
#    'id': 'Airblock_LECSCORB_019LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.76194444444444, 37.5194444444444],
#      [-3.76194444444444, 37.7797222222222],
#      [-3.23416666666667, 37.7797222222222],
#      [-3.23416666666667, 37.5194444444444],
#      [-3.76194444444444, 37.5194444444444]]],
#    'id': 'Airblock_LECSJAEA_041LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.76194444444444, 37.5194444444444],
#      [-3.76194444444444, 37.7797222222222],
#      [-3.23416666666667, 37.7797222222222],
#      [-3.23416666666667, 37.5194444444444],
#      [-3.76194444444444, 37.5194444444444]]],
#    'id': 'Airblock_LECSJAEB_041LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.06611111111111, 36.3291666666667],
#      [-4.06611111111111, 37.0],
#      [-3.31805555555556, 37.0],
#      [-3.31805555555556, 36.3291666666667],
#      [-4.06611111111111, 36.3291666666667]]],
#    'id': 'Airblock_LECSMALA_007LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.20833333333333, 37.0],
#      [-4.20833333333333, 37.5263888888889],
#      [-3.2625, 37.5263888888889],
#      [-3.2625, 37.0],
#      [-4.20833333333333, 37.0]]],
#    'id': 'Airblock_LECSMALA_040LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.39333333333333, 37.3105555555556],
#      [-4.39333333333333, 37.5333333333333],
#      [-3.76194444444444, 37.5333333333333],
#      [-3.76194444444444, 37.3105555555556],
#      [-4.39333333333333, 37.3105555555556]]],
#    'id': 'Airblock_LECSMALA_042LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.82944444444444, 36.2422222222222],
#      [-4.82944444444444, 36.6833333333333],
#      [-3.91444444444444, 36.6833333333333],
#      [-3.91444444444444, 36.2422222222222],
#      [-4.82944444444444, 36.2422222222222]]],
#    'id': 'Airblock_LECSMALA_750LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.57694444444444, 36.3291666666667],
#      [-4.57694444444444, 37.3386111111111],
#      [-3.90416666666667, 37.3386111111111],
#      [-3.90416666666667, 36.3291666666667],
#      [-4.57694444444444, 36.3291666666667]]],
#    'id': 'Airblock_LECSMALA_751LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.75777777777778, 36.7180555555556],
#      [-4.75777777777778, 37.1533333333333],
#      [-4.47638888888889, 37.1533333333333],
#      [-4.47638888888889, 36.7180555555556],
#      [-4.75777777777778, 36.7180555555556]]],
#    'id': 'Airblock_LECSMALA_754LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.06611111111111, 36.3291666666667],
#      [-4.06611111111111, 37.0],
#      [-3.31805555555556, 37.0],
#      [-3.31805555555556, 36.3291666666667],
#      [-4.06611111111111, 36.3291666666667]]],
#    'id': 'Airblock_LECSMALB_007LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.20833333333333, 37.0],
#      [-4.20833333333333, 37.5263888888889],
#      [-3.2625, 37.5263888888889],
#      [-3.2625, 37.0],
#      [-4.20833333333333, 37.0]]],
#    'id': 'Airblock_LECSMALB_040LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.39333333333333, 37.3105555555556],
#      [-4.39333333333333, 37.5333333333333],
#      [-3.76194444444444, 37.5333333333333],
#      [-3.76194444444444, 37.3105555555556],
#      [-4.39333333333333, 37.3105555555556]]],
#    'id': 'Airblock_LECSMALB_042LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.82944444444444, 36.2422222222222],
#      [-4.82944444444444, 36.6833333333333],
#      [-3.91444444444444, 36.6833333333333],
#      [-3.91444444444444, 36.2422222222222],
#      [-4.82944444444444, 36.2422222222222]]],
#    'id': 'Airblock_LECSMALB_750LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.57694444444444, 36.3291666666667],
#      [-4.57694444444444, 37.3386111111111],
#      [-3.90416666666667, 37.3386111111111],
#      [-3.90416666666667, 36.3291666666667],
#      [-4.57694444444444, 36.3291666666667]]],
#    'id': 'Airblock_LECSMALB_751LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.75777777777778, 36.7180555555556],
#      [-4.75777777777778, 37.1533333333333],
#      [-4.47638888888889, 37.1533333333333],
#      [-4.47638888888889, 36.7180555555556],
#      [-4.75777777777778, 36.7180555555556]]],
#    'id': 'Airblock_LECSMALB_754LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.10055555555556, 37.3386111111111],
#      [-5.10055555555556, 37.5333333333333],
#      [-4.25555555555556, 37.5333333333333],
#      [-4.25555555555556, 37.3386111111111],
#      [-5.10055555555556, 37.3386111111111]]],
#    'id': 'Airblock_LECSMARA_003LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.58694444444444, 37.0144444444444],
#      [-5.58694444444444, 37.5333333333333],
#      [-5.0625, 37.5333333333333],
#      [-5.0625, 37.0144444444444],
#      [-5.58694444444444, 37.0144444444444]]],
#    'id': 'Airblock_LECSMARA_018LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.55083333333333, 37.1533333333333],
#      [-4.55083333333333, 37.3594444444444],
#      [-4.39333333333333, 37.3594444444444],
#      [-4.39333333333333, 37.1533333333333],
#      [-4.55083333333333, 37.1533333333333]]],
#    'id': 'Airblock_LECSMARA_752LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.74638888888889, 36.8711111111111],
#      [-4.74638888888889, 37.3594444444444],
#      [-4.51861111111111, 37.3594444444444],
#      [-4.51861111111111, 36.8711111111111],
#      [-4.74638888888889, 36.8711111111111]]],
#    'id': 'Airblock_LECSMARA_753LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.10055555555556, 37.3386111111111],
#      [-5.10055555555556, 37.5333333333333],
#      [-4.25555555555556, 37.5333333333333],
#      [-4.25555555555556, 37.3386111111111],
#      [-5.10055555555556, 37.3386111111111]]],
#    'id': 'Airblock_LECSMARB_003LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.58694444444444, 37.0144444444444],
#      [-5.58694444444444, 37.5333333333333],
#      [-5.0625, 37.5333333333333],
#      [-5.0625, 37.0144444444444],
#      [-5.58694444444444, 37.0144444444444]]],
#    'id': 'Airblock_LECSMARB_018LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.55083333333333, 37.1533333333333],
#      [-4.55083333333333, 37.3594444444444],
#      [-4.39333333333333, 37.3594444444444],
#      [-4.39333333333333, 37.1533333333333],
#      [-4.55083333333333, 37.1533333333333]]],
#    'id': 'Airblock_LECSMARB_752LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.74638888888889, 36.8711111111111],
#      [-4.74638888888889, 37.3594444444444],
#      [-4.51861111111111, 37.3594444444444],
#      [-4.51861111111111, 36.8711111111111],
#      [-4.74638888888889, 36.8711111111111]]],
#    'id': 'Airblock_LECSMARB_753LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.68055555555556, 37.2],
#      [-6.68055555555556, 37.4241666666667],
#      [-6.25277777777778, 37.4241666666667],
#      [-6.25277777777778, 37.2],
#      [-6.68055555555556, 37.2]]],
#    'id': 'Airblock_LECSMNTA_015LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.68055555555556, 37.2],
#      [-6.68055555555556, 37.4241666666667],
#      [-6.25277777777778, 37.4241666666667],
#      [-6.25277777777778, 37.2],
#      [-6.68055555555556, 37.2]]],
#    'id': 'Airblock_LECSMNTB_015LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.38333333333333, 36.8916666666667],
#      [-7.38333333333333, 37.7986111111111],
#      [-6.54277777777778, 37.7986111111111],
#      [-6.54277777777778, 36.8916666666667],
#      [-7.38333333333333, 36.8916666666667]]],
#    'id': 'Airblock_LECSMNTB_031LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.13333333333333, 36.2361111111111],
#      [-7.13333333333333, 37.275],
#      [-5.58694444444444, 37.275],
#      [-5.58694444444444, 36.2361111111111],
#      [-7.13333333333333, 36.2361111111111]]],
#    'id': 'Airblock_LECSSEKO_013LE',
#    'type': 'Feature'},
#   {'geometry': [[[-6.54277777777778, 37.0],
#      [-6.54277777777778, 38.0],
#      [-5.11972222222222, 38.0],
#      [-5.11972222222222, 37.0],
#      [-6.54277777777778, 37.0]]],
#    'id': 'Airblock_LECSSEOX_012LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.26527777777778, 37.4241666666667],
#      [-7.26527777777778, 39.0005555555556],
#      [-4.52972222222222, 39.0005555555556],
#      [-4.52972222222222, 37.4241666666667],
#      [-7.26527777777778, 37.4241666666667]]],
#    'id': 'Airblock_LECSSEOX_020LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.61333333333333, 38.8038888888889],
#      [-4.61333333333333, 39.0005555555556],
#      [-4.26666666666667, 39.0005555555556],
#      [-4.26666666666667, 38.8038888888889],
#      [-4.61333333333333, 38.8038888888889]]],
#    'id': 'Airblock_LECSSEOX_307LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.12638888888889, 38.4033333333333],
#      [-7.12638888888889, 39.0],
#      [-6.16527777777778, 39.0],
#      [-6.16527777777778, 38.4033333333333],
#      [-7.12638888888889, 38.4033333333333]]],
#    'id': 'Airblock_LECSSEOX_420LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.3, 38.3461111111111],
#      [-7.3, 38.7313888888889],
#      [-7.12638888888889, 38.7313888888889],
#      [-7.12638888888889, 38.3461111111111],
#      [-7.3, 38.3461111111111]]],
#    'id': 'Airblock_LECSSEOX_503LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.31666666666667, 37.7986111111111],
#      [-7.31666666666667, 37.8955555555556],
#      [-7.24805555555556, 37.8955555555556],
#      [-7.24805555555556, 37.7986111111111],
#      [-7.31666666666667, 37.7986111111111]]],
#    'id': 'Airblock_LECSSEOX_504LE',
#    'type': 'Feature'},
#   {'geometry': [[[-7.23, 37.9994444444444],
#      [-7.23, 38.3461111111111],
#      [-7.0, 38.3461111111111],
#      [-7.0, 37.9994444444444],
#      [-7.23, 37.9994444444444]]],
#    'id': 'Airblock_LECSSEOX_554LP',
#    'type': 'Feature'},
#   {'geometry': [[[-7.24805555555556, 37.8955555555556],
#      [-7.24805555555556, 38.0008333333333],
#      [-7.12583333333333, 38.0008333333333],
#      [-7.12583333333333, 37.8955555555556],
#      [-7.24805555555556, 37.8955555555556]]],
#    'id': 'Airblock_LECSSEOX_555LP',
#    'type': 'Feature'},
#   {'geometry': [[[-6.7175, 35.8333333333333],
#      [-6.7175, 37.0],
#      [-5.03861111111111, 37.0],
#      [-5.03861111111111, 35.8333333333333],
#      [-6.7175, 35.8333333333333]]],
#    'id': 'Airblock_LECSVEJA_001LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.2175, 37.5816666666667],
#      [-3.2175, 39.0],
#      [-1.66777777777778, 39.0],
#      [-1.66777777777778, 37.5816666666667],
#      [-3.2175, 37.5816666666667]]],
#    'id': 'Airblock_LECSYSTE_011LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.0, 38.4333333333333],
#      [-3.0, 39.0],
#      [-1.48277777777778, 39.0],
#      [-1.48277777777778, 38.4333333333333],
#      [-3.0, 38.4333333333333]]],
#    'id': 'Airblock_LECSYSTE_423LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.52305555555556, 42.0733333333333],
#      [2.52305555555556, 42.4658333333333],
#      [2.91583333333333, 42.4658333333333],
#      [2.91583333333333, 42.0733333333333],
#      [2.52305555555556, 42.0733333333333]]],
#    'id': 'Airblock_LEGETA_074LE',
#    'type': 'Feature'},
#   {'geometry': [[[2.50416666666667, 41.7311111111111],
#      [2.50416666666667, 42.4802777777778],
#      [3.39416666666667, 42.4802777777778],
#      [3.39416666666667, 41.7311111111111],
#      [2.50416666666667, 41.7311111111111]]],
#    'id': 'Airblock_LEGETA_078LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.39722222222222, 40.2211111111111],
#      [-4.39722222222222, 40.4833333333333],
#      [-3.975, 40.4833333333333],
#      [-3.975, 40.2211111111111],
#      [-4.39722222222222, 40.2211111111111]]],
#    'id': 'Airblock_LEMD932A_932LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.39722222222222, 40.2211111111111],
#      [-4.39722222222222, 40.4833333333333],
#      [-3.975, 40.4833333333333],
#      [-3.975, 40.2211111111111],
#      [-4.39722222222222, 40.2211111111111]]],
#    'id': 'Airblock_LEMD932B_932LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.34222222222222, 39.7333333333333],
#      [-4.34222222222222, 40.3016666666667],
#      [-3.32833333333333, 40.3016666666667],
#      [-3.32833333333333, 39.7333333333333],
#      [-4.34222222222222, 39.7333333333333]]],
#    'id': 'Airblock_LEMD934A_934LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.34222222222222, 39.7333333333333],
#      [-4.34222222222222, 40.3016666666667],
#      [-3.32833333333333, 40.3016666666667],
#      [-3.32833333333333, 39.7333333333333],
#      [-4.34222222222222, 39.7333333333333]]],
#    'id': 'Airblock_LEMD934B_934LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.81166666666667, 39.9444444444444],
#      [-3.81166666666667, 40.2744444444444],
#      [-3.42638888888889, 40.2744444444444],
#      [-3.42638888888889, 39.9444444444444],
#      [-3.81166666666667, 39.9444444444444]]],
#    'id': 'Airblock_LEMD977A_977LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.81166666666667, 39.9444444444444],
#      [-3.81166666666667, 40.2744444444444],
#      [-3.42638888888889, 40.2744444444444],
#      [-3.42638888888889, 39.9444444444444],
#      [-3.81166666666667, 39.9444444444444]]],
#    'id': 'Airblock_LEMD977B_977LE',
#    'type': 'Feature'},
#   {'geometry': [[[-3.81166666666667, 39.9444444444444],
#      [-3.81166666666667, 40.2744444444444],
#      [-3.42638888888889, 40.2744444444444],
#      [-3.42638888888889, 39.9444444444444],
#      [-3.81166666666667, 39.9444444444444]]],
#    'id': 'Airblock_LEMD977C_977LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.74638888888889, 36.8711111111111],
#      [-4.74638888888889, 37.3594444444444],
#      [-4.51861111111111, 37.3594444444444],
#      [-4.51861111111111, 36.8711111111111],
#      [-4.74638888888889, 36.8711111111111]]],
#    'id': 'Airblock_LEMGCEN_753LE',
#    'type': 'Feature'},
#   {'geometry': [[[-4.57694444444444, 36.3291666666667],
#      [-4.57694444444444, 37.3386111111111],
#      [-3.90416666666667, 37.3386111111111],
#      [-3.90416666666667, 36.3291666666667],
#      [-4.57694444444444, 36.3291666666667]]],
#    'id': 'Airblock_LEMGE_751LE',
#    'type': 'Feature'},
#   {'geometry': [[[-5.15, 36.85],
#      [-5.15, 37.3833333333333],
#      [-4.55083333333333, 37.3833333333333],
#      [-4.55083333333333, 36.85],
#      [-5.15, 36.85]]],
#    'id': 'Airblock_LEMGW_755LE',
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
import folium
spainmap = folium.Map(location=[35, 5], zoom_start=3, control_scale=True, prefer_canvas=True)
#spainmap.choropleth(geo_str=str(spain))
#spainmap.save(outfile='maps/mapspain.html')
#mapspain
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# One comment on this construction. We are loosing altitude info here. I would need to construct the Polygon-Collection with a different method to preserve altitude information.

# %%
print(sector_dict['Airspace_LEBLBL1_411'])
# Out:
# {'type': 'Polygon', 'coordinates': [[1.85638888888889, 41.4630555555556], [1.85638888888889, 41.8480555555556], [2.84083333333333, 41.8480555555556], [2.84083333333333, 41.4630555555556], [1.85638888888889, 41.4630555555556], [2.50416666666667, 41.6713888888889], [2.50416666666667, 41.9577777777778], [3.00638888888889, 41.9577777777778], [3.00638888888889, 41.6713888888889], [2.50416666666667, 41.6713888888889], [1.88277777777778, 41.2966666666667], [1.88277777777778, 41.6469444444444], [2.18694444444444, 41.6469444444444], [2.18694444444444, 41.2966666666667], [1.88277777777778, 41.2966666666667], [2.09777777777778, 41.2966666666667], [2.09777777777778, 41.5808333333333], [2.5675, 41.5808333333333], [2.5675, 41.2966666666667], [2.09777777777778, 41.2966666666667]]}

# %%
#write the dict back into a DataFrame
# Out:
# 358
# 0        Airspace_LEBLBL1_411
# 436      Airspace_LEBLBL1_411
# 872      Airspace_LEBLBL1_411
# 1308     Airspace_LEBLBL1_411
# 1744     Airspace_LEBLBL2_411
# 2180     Airspace_LEBLDDN_411
# 2616     Airspace_LEBLDDN_411
# 3052     Airspace_LEBLDDS_411
# 3488     Airspace_LEBLDDS_411
# 3924     Airspace_LEBLDDS_411
# 4360     Airspace_LEBLDDS_411
# 4796    Airspace_LEBLGARI_411
# 5232    Airspace_LEBLGONA_411
# 5668    Airspace_LEBLGONA_411
# 6104    Airspace_LEBLGONA_411
# 6540     Airspace_LEBLGR1_411
# 6976     Airspace_LEBLGR1_411
# 7412     Airspace_LEBLGR1_411
# 7848     Airspace_LEBLGR1_411
# 8284     Airspace_LEBLGR2_411
# Name: airspace, dtype: object

# %% [markdown]
# # Old stuff

# %%
import pandas as pd

# %%
import pandas as pd
regs = pd.read_csv('data/CRIDA-Regulations-20160401-20160430.csv',';')
regs = regs.set_index('RegulationId')
regs = regs.sort_index()
regs.head(20)
# Out:
#               dateReference    RegulationStart TrafficVolumeSet  \
# RegulationId
# AR1ORT01           20160401  20160401 00:00:00           SCENAR
# AR1ORT27           20160427  20160427 17:00:00           SCENAR
# AR1ORT28           20160428  20160428 00:00:00           SCENAR
# AR1ORT29           20160429  20160429 00:00:00           SCENAR
# AR2RV01            20160401  20160401 00:00:00           SCENAR
# AR2RV27            20160427  20160427 17:00:00           SCENAR
# AR2RV28            20160428  20160428 00:00:00           SCENAR
# AR2RV29            20160429  20160429 00:00:00           SCENAR
# ASU17M             20160417  20160417 05:50:00          LECMFMP
# BBAS28             20160428  20160428 09:40:00          LECBFMP
# BBDX01N            20160401  20160401 00:00:00          LFBBFMP
# BDX28              20160428  20160428 21:00:00          LFBBFMP
# BFBDX01            20160401  20160401 04:00:00          LFBBFMP
# BFBDX28            20160428  20160428 04:00:00          LFBBFMP
# BFBDX28A           20160428  20160428 15:00:00          LFBBFMP
# BL12N24            20160424  20160424 21:20:00         LECBFMP1
# BL402              20160402  20160402 06:40:00          LFBBFMP
# BLI10              20160410  20160410 20:20:00          LECMFMP
# BP12311            20160411  20160411 05:00:00          LFBBFMP
# BP12318            20160418  20160418 05:30:00          LFBBFMP
#
#              ReferenceLocation ReferenceLocationType TrafficVolume  \
# RegulationId
# AR1ORT01                 ORTIS                    SP        AR1ORT
# AR1ORT27                 ORTIS                    SP        AR1ORT
# AR1ORT28                 ORTIS                    SP        AR1ORT
# AR1ORT29                 ORTIS                    SP        AR1ORT
# AR2RV01                  SARAY                    SP         AR2RV
# AR2RV27                  SARAY                    SP         AR2RV
# AR2RV28                  SARAY                    SP         AR2RV
# AR2RV29                  SARAY                    SP         AR2RV
# ASU17M                 LECMASU                    AS       LECMASU
# BBAS28                 LECBBAS                    AS      LECBBAS1
# BBDX01N                LFBBBDX                    AS        LFBBDX
# BDX28                  LFBBBDX                    AS        LFBBDX
# BFBDX01               LFBBFBDX                    AS       LFBFBDX
# BFBDX28               LFBBFBDX                    AS       LFBFBDX
# BFBDX28A              LFBBFBDX                    AS       LFBFBDX
# BL12N24               LEBLCORE                    AS         BL12N
# BL402                   LFBBL4                    AS         LFBL4
# BLI10                  LECMBLI                    AS       LECMBLI
# BP12311               LFBBP123                    AS       LFBP123
# BP12318               LFBBP123                    AS       LFBP123
#
#                   RegulationEnd RegulationActivity RegulationCancelTime  \
# RegulationId
# AR1ORT01      20160401 04:00:00                  T                  NaN
# AR1ORT27      20160428 00:00:00                  T                  NaN
# AR1ORT28      20160429 00:00:00                  T                  NaN
# AR1ORT29      20160429 04:00:00                  T                  NaN
# AR2RV01       20160401 04:00:00                  T                  NaN
# AR2RV27       20160428 00:00:00                  T                  NaN
# AR2RV28       20160429 00:00:00                  T                  NaN
# AR2RV29       20160429 04:00:00                  T                  NaN
# ASU17M        20160417 07:40:00                  C    20160417 06:19:27
# BBAS28        20160428 11:20:00                  T                  NaN
# BBDX01N       20160401 04:00:00                  C    20160331 17:44:05
# BDX28         20160428 23:59:00                  C    20160428 13:53:40
# BFBDX01       20160401 05:00:00                  C    20160331 17:44:28
# BFBDX28       20160428 21:00:00                  C    20160428 07:03:13
# BFBDX28A      20160428 21:00:00                  C    20160428 13:20:48
# BL12N24       20160424 22:20:00                  C    20160424 21:03:11
# BL402         20160402 08:00:00                  C    20160402 06:15:58
# BLI10         20160410 21:20:00                  C    20160410 20:27:56
# BP12311       20160411 09:20:00                  C    20160411 04:28:42
# BP12318       20160418 06:30:00                  C    20160418 04:24:39
#
#               RegulationDuration  AiracCycle RegulationCategory  \
# RegulationId
# AR1ORT01                     240         411                  T
# AR1ORT27                     420         411                  T
# AR1ORT28                    1440         412                  T
# AR1ORT29                     240         412                  T
# AR2RV01                      240         411                  T
# AR2RV27                      420         411                  T
# AR2RV28                     1440         412                  T
# AR2RV29                      240         412                  T
# ASU17M                        29         411                  T
# BBAS28                        99         412                  T
# BBDX01N                     -375         411                  T
# BDX28                       -426         412                  T
# BFBDX01                     -615         411                  T
# BFBDX28                      183         412                  T
# BFBDX28A                     -99         412                  T
# BL12N24                      -16         411                  T
# BL402                        -24         411                  T
# BLI10                          7         411                  T
# BP12311                      -31         411                  T
# BP12318                      -65         411                  T
#
#              RegulationReasonCode RegulationDescription
# RegulationId
# AR1ORT01                        R                   NaN
# AR1ORT27                        R                   NaN
# AR1ORT28                        R                   NaN
# AR1ORT29                        R                   NaN
# AR2RV01                         R                   NaN
# AR2RV27                         R                   NaN
# AR2RV28                         R                   NaN
# AR2RV29                         R                   NaN
# ASU17M                          C                   NaN
# BBAS28                          O  DUE TO FRENCH STRIKE
# BBDX01N                         I                   NaN
# BDX28                           I                   NaN
# BFBDX01                         I                   NaN
# BFBDX28                         I                   NaN
# BFBDX28A                        I                   NaN
# BL12N24                         C                   NaN
# BL402                           C                   NaN
# BLI10                           C                   NaN
# BP12311                         C                   NaN
# BP12318                         C                   NaN

# %%
filtered = regs[['TrafficVolume', 'ReferenceLocation']]

filtered = filtered.drop_duplicates()

print(len(filtered))
filtered.head(20)
# Out:
# 581
#              TrafficVolume ReferenceLocation
# RegulationId
# AR1ORT01            AR1ORT             ORTIS
# AR2RV01              AR2RV             SARAY
# ASU17M             LECMASU           LECMASU
# BBAS28            LECBBAS1           LECBBAS
# BBDX01N             LFBBDX           LFBBBDX
# BFBDX01            LFBFBDX          LFBBFBDX
# BL12N24              BL12N          LEBLCORE
# BL402                LFBL4            LFBBL4
# BLI10              LECMBLI           LECMBLI
# BP12311            LFBP123          LFBBP123
# BP311                LFBP3            LFBBP3
# BPT07                LFBPT            LFBBPT
# BR221                LFBR2            LFBBR2
# BR402                LFBR4            LFBBR4
# BRL105              LFBRL1           LFBBRL1
# BRL1219            LFBRL12          LFBBRL12
# BRL205              LFBRL2           LFBBRL2
# BRL28                LFBRL            LFBBRL
# BRL305              LFBRL3           LFBBRL3
# BRL3428M           LFBRL34          LFBBRL34

# %%
vc = filtered.TrafficVolume.value_counts()
vc
# Out:
# FL10NTM     2
# FL11NTM     2
# RR1RNE      1
# FL2L1K      1
# LFRVKW      1
# EDUSAL1A    1
# LFSBBM      1
# LFPO        1
# LSTSAW      1
# LIMF        1
# EDWFLG      1
# MASH5WH     1
# LECBLVU1    1
# LFEUN4      1
# FL1BR4      1
# EGTTRED     1
# MASBOLN     1
# FL3BEH      1
# GCXOARR     1
# EDUDI2C     1
# EDG1LA05    1
# LFPN        1
# FL1TLU      1
# LFMWW       1
# LFEURMN4    1
# LIRN        1
# FL5LVU      1
# LFMD        1
# EDG6PAD     1
# LQ3LU       1
#            ..
# GCLPDEP     1
# EGPDCS      1
# LCS12WX     1
# MASD5JH     1
# LFBDSIV     1
# RR1MAR      1
# LFRGA       1
# EDDSARR     1
# LEBLARR     1
# LIMC        1
# LFSBARR     1
# LGSTRDE8    1
# LSZBAORX    1
# LEMGARR1    1
# LIRADST     1
# EPWR        1
# LCS2        1
# LFFLMHJ1    1
# LFFAOMLM    1
# LFLBARR     1
# LFRQXU      1
# LGSTRAR4    1
# LEBLT1E1    1
# LIPE        1
# GCCCIGC     1
# FL7DGU      1
# EDGG7       1
# RR5EDG4     1
# LGAVDEP     1
# LFTZ        1
# Name: TrafficVolume, dtype: int64

# %%
mask = filtered[ filtered['TrafficVolume']== 'FL10NTM']

mask
# Out:
#              TrafficVolume ReferenceLocation
# RegulationId
# FL10NM02           FL10NTM         EDUUNTM33
# FL10NT30           FL10NTM         EDUUNTM3C

# %%
len(vc)
# Out:
# 579

# %%
#Compare number of WX based and non WX based regulations
regswx = regs.ix[ (regs['RegulationReasonCode']== 'W') ]
regsnonwx = regs.ix[ (regs['RegulationReasonCode']!= 'W') ]
a = regswx['TrafficVolumeSet'].count()
b = regsnonwx['TrafficVolumeSet'].count()
print(a)
print(b)
# Out:
# 173
# 2476

# %%
#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt

#Daten setzen
labels = 'WX-regulations' , 'other regulations'
sizes = [a,b]
colors = ['gold','lightcoral']
explode= (0.1,0)

#plotten
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=30)
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# ([<matplotlib.patches.Wedge at 0x7f72f4b75c50>,
#   <matplotlib.patches.Wedge at 0x7f72f4b0e550>],
#  [<matplotlib.text.Text at 0x7f72f4b02a58>,
#   <matplotlib.text.Text at 0x7f72f4b16358>],
#  [<matplotlib.text.Text at 0x7f72f4b02fd0>,
#   <matplotlib.text.Text at 0x7f72f4b168d0>])

# %%
start = regswx['RegulationStart'].min()
start
# Out:
# '20160401 04:40:00'

# %%
end = regswx['RegulationStart'].max()
end
# Out:
# '20160430 05:00:00'

# %%
#Part of WX -regulations where sector with bad WX is the same as regulated sector

regssame = regswx.ix[ (regswx['TrafficVolume']== regswx['ReferenceLocation'] ) ]

c = regssame['TrafficVolume'].count()

# %%
#Insert this number into pie chart above
import matplotlib.pyplot as plt
# %matplotlib notebook

#Daten setzen
labels = ('WX-regs w/different RefLoc' ,'WX regs w/same RefLoc', 'other regs')
sizes = [a-c, c, b]
colors = ['gold', 'lightblue', 'lightcoral']
explode= (0,0.1,0)

#plotten
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=30)
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">
# ([<matplotlib.patches.Wedge at 0x7f0e8745a160>,
#   <matplotlib.patches.Wedge at 0x7f0e87460a20>,
#   <matplotlib.patches.Wedge at 0x7f0e87470320>],
#  [<matplotlib.text.Text at 0x7f0e8745af28>,
#   <matplotlib.text.Text at 0x7f0e87467828>,
#   <matplotlib.text.Text at 0x7f0e87478128>],
#  [<matplotlib.text.Text at 0x7f0e874604e0>,
#   <matplotlib.text.Text at 0x7f0e87467da0>,
#   <matplotlib.text.Text at 0x7f0e874786a0>])

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
# create new figure, axes instances.
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
# setup mercator map projection.
m = Basemap(llcrnrlon=-100.,llcrnrlat=20.,urcrnrlon=20.,urcrnrlat=60.,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',projection='merc',\
            lat_0=40.,lon_0=-20.,lat_ts=20.)
# nylat, nylon are lat/lon of New York
nylat = 40.78; nylon = -73.98
# lonlat, lonlon are lat/lon of London.
lonlat = 51.53; lonlon = 0.08
# draw great circle route between NY and London
m.drawgreatcircle(nylon,nylat,lonlon,lonlat,linewidth=2,color='b')
m.drawcoastlines()
m.fillcontinents()
# draw parallels
m.drawparallels(np.arange(10,90,20),labels=[1,1,0,1])
# draw meridians
m.drawmeridians(np.arange(-180,180,30),labels=[1,1,0,1])
ax.set_title('Great Circle from New York to London')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.3999771332749">
# /home/joerg/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/joerg/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/joerg/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
av = regswx['RegulationDuration'].mean()
av
# Out:
# 121.84393063583815
